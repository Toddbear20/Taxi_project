# %%
import pandas as pd

df = pd.read_excel('서울시_구별_장애인유형_계.xlsx')
df['구별 총 장애인 수'] = df.sum(axis= 1)
df.columns
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_11500\3845941216.py:4: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df['구별 총 장애인 수'] = df.sum(axis= 1)
# Index(['구별', '지체_계', '뇌병변_계', '시각_계', '청각_계', '언어_계', '지적장애_계', '자폐성_계',
#        '정신장애_계', '신장장애_계', '심장장애_계', '호흡기_계', '간_계', '안면_계', '장루요루_계', '뇌전증_계',
#        '구별 총 장애인 수'],
#       dtype='object')

# %%
df_w = pd.DataFrame(columns=['구별','구별_지체비율', '구별_뇌병변비율','구별_시각비율','구별_청각비율','구별_언어비율','구별_지적비율','구별_자폐비율','구별_정신장애비율','구별_신장비율','구별_심장비율','구별_호흡기비율','구별_간비율','구별_안면비율','구별_장루요루비율','구별_뇌전증비율'])

df_w['구별'] = df['구별']
df_w['구별_지체비율'] = df['지체_계']/df['구별 총 장애인 수']
df_w['구별_뇌병변비율'] = df['뇌병변_계']/df['구별 총 장애인 수']
df_w['구별_시각비율'] = df['시각_계']/df['구별 총 장애인 수']
df_w['구별_청각비율'] = df['청각_계']/df['구별 총 장애인 수']
df_w['구별_언어비율'] = df['언어_계']/df['구별 총 장애인 수']
df_w['구별_지적비율'] = df['지적장애_계']/df['구별 총 장애인 수']
df_w['구별_자폐비율'] = df['자폐성_계']/df['구별 총 장애인 수']
df_w['구별_정신장애비율'] = df['정신장애_계']/df['구별 총 장애인 수']
df_w['구별_신장비율'] = df['신장장애_계']/df['구별 총 장애인 수']
df_w['구별_심장비율'] = df['심장장애_계']/df['구별 총 장애인 수']
df_w['구별_호흡기비율'] = df['호흡기_계']/df['구별 총 장애인 수']
df_w['구별_간비율'] = df['간_계']/df['구별 총 장애인 수']
df_w['구별_안면비율'] = df['안면_계']/df['구별 총 장애인 수']
df_w['구별_장루요루비율'] = df['장루요루_계']/df['구별 총 장애인 수']
df_w['구별_뇌전증비율'] = df['뇌전증_계']/df['구별 총 장애인 수']



df_w = df_w.set_index('구별')
df_w
# Out:
#        구별_지체비율  구별_뇌병변비율   구별_시각비율   구별_청각비율   구별_언어비율   구별_지적비율   구별_자폐비율  \
# 구별
# 종로구   0.423006  0.093270  0.118570  0.160061  0.007590  0.067634  0.017710
# 중구    0.443379  0.100639  0.127263  0.152645  0.005680  0.052716  0.013135
# 용산구   0.423237  0.098491  0.121390  0.149232  0.008457  0.068436  0.016524
# 성동구   0.448511  0.101205  0.100585  0.150744  0.009571  0.061680  0.017281
# 광진구   0.441933  0.097282  0.107076  0.147637  0.007345  0.065780  0.015343
# 동대문구  0.455278  0.102011  0.097693  0.156528  0.009022  0.057933  0.011019
# 중랑구   0.464951  0.102864  0.102864  0.126885  0.008498  0.064990  0.012477
# 성북구   0.438442  0.102865  0.110632  0.149580  0.009608  0.065528  0.014268
# 강북구   0.433343  0.098534  0.109744  0.159816  0.008106  0.070020  0.010060
# 도봉구   0.428627  0.107908  0.104837  0.150915  0.007582  0.072810  0.012549
# 노원구   0.424695  0.104817  0.101286  0.136448  0.009329  0.086047  0.014831
# ...

# %%
df_s = pd.read_excel('서울시_구별_성별_장애인유형.xlsx')
df_s2 = df_s.set_index('구별')
df_s2.columns
# Out:
# Index(['지체_남자', '지체_여자', '뇌병변_남자', '뇌병변_여자', '시각_남자', '시각_여자', '청각_남자',
#        '청각_여자', '언어_남자', '언어_여자', '지적장애_남자', '지적장애_여자', '자폐성_남자', '자폐성_여자',
#        '정신장애_남자', '정신장애_여자', '신장장애_남자', '신장장애_여자', '심장장애_남자', '심장장애_여자',
#        '호흡기_남자', '호흡기_여자', '간_남자', '간_여자', '안면_남자', '안면_여자', '장루요루_남자',
#        '장루요루_여자', '뇌전증_남자', '뇌전증_여자'],
#       dtype='object')

# %%
for i in range(25):
    df_s2.iloc[i]=df_s2.iloc[i].map(lambda x: x/df['구별 총 장애인 수'][i])

df_s2
# Out:
#          지체_남자     지체_여자    뇌병변_남자    뇌병변_여자     시각_남자     시각_여자     청각_남자  \
# 구별
# 종로구   0.231068  0.191938  0.058357  0.034913  0.074549  0.044021  0.088885
# 중구    0.241747  0.201633  0.066028  0.034611  0.078097  0.049166  0.085020
# 용산구   0.231330  0.191907  0.058418  0.040073  0.074291  0.047099  0.081577
# 성동구   0.252038  0.196473  0.061326  0.039879  0.057781  0.042804  0.080911
# 광진구   0.246389  0.195544  0.055741  0.041541  0.065943  0.041133  0.084877
# 동대문구  0.254285  0.200992  0.060704  0.041307  0.061348  0.036345  0.086674
# 중랑구   0.262514  0.202437  0.060471  0.042393  0.061257  0.041607  0.072211
# 성북구   0.240996  0.197446  0.059947  0.042918  0.065643  0.044989  0.083420
# 강북구   0.241621  0.191722  0.058580  0.039954  0.061339  0.048405  0.090658
# 도봉구   0.241307  0.187320  0.062876  0.045033  0.063595  0.041242  0.082680
# 노원구   0.229817  0.194878  0.059322  0.045495  0.055902  0.045384  0.070064
# ...

# %%
import pandas as pd

df = pd.read_excel('서울시_구별_장애인유형_계_국가_도시_합계.xlsx')
df=df.drop(columns=['국가', '도시'])
df=df.set_index('구별')
df
for i in range(25):
    df.iloc[i]=df.iloc[i].map(lambda x: x/df['합계'][i])
df=df.drop(columns=['합계'])
df1 = pd.DataFrame(columns=['외부신체장애','내부기관장애','정신적장애'])
df1['외부신체장애'] = df['지체_계']+df['뇌병변_계']+df['시각_계']+df['청각_계']+df['언어_계']+df['안면_계']
df1['내부기관장애'] = df['신장장애_계']+df['심장장애_계']+df['호흡기_계']+df['간_계']+df['장루요루_계']+df['뇌전증_계']
df1['정신적장애'] = df['지적장애_계'] + df['자폐성_계']+df['정신장애_계']

# %%
pd.
# Out:
#         외부신체장애    내부기관장애     정신적장애
# 구별
# 종로구   0.803677  0.066790  0.129533
# 중구    0.830848  0.066560  0.102591
# 용산구   0.801457  0.076893  0.121650
# 성동구   0.811680  0.073290  0.115030
# 광진구   0.802008  0.073615  0.124378
# 동대문구  0.821691  0.068566  0.109744
# 중랑구   0.806750  0.073734  0.119517
# 성북구   0.812162  0.070820  0.117018
# 강북구   0.809888  0.067088  0.123024
# 도봉구   0.800915  0.070065  0.129020
# 노원구   0.777840  0.066384  0.155776
# 은평구   0.777211  0.068395  0.154394
# 서대문구  0.802209  0.076273  0.121517
# 마포구   0.801854  0.075628  0.122518
# 양천구   0.809415  0.068816  0.121769
# 강서구   0.786345  0.071744  0.141911
# 구로구   0.812779  0.067323  0.119898
# 금천구   0.815587  0.066242  0.118171
# 영등포구  0.820904  0.071059  0.108037
# 동작구   0.812027  0.073732  0.114240
# 관악구   0.803374  0.071842  0.124784
# 서초구   0.778156  0.088524  0.133320
# 강남구   0.753326  0.083652  0.163022
# 송파구   0.775938  0.082334  0.141727
# 강동구   0.789997  0.072634  0.137370

# %%
df2 = pd.read_csv('장애인+현황(등급별_동별)_20220821143043.csv')
df2=df2.drop(columns = '동별(1)')
df3=df2.drop(columns=['2021.1','2021.2','2021.4','2021.5','2021.7','2021.8'])
df5 = df3.iloc[4:]

df4 = pd.DataFrame(columns=['심한장애','안 심한장애'])

# df4['심한장애'] = df5['2021.3']/df5['2021']
# df4['안 심한장애']=df5['2021.6']/df5['2021']

arr=df5['2021'].astype('int')
arr1=df5['2021.3'].astype('int')
arr2=df5['2021.6'].astype('int')

df4['심한장애'] = arr1/arr
df4['안 심한장애']=arr2/arr

df4=df4.set_index(df5['동별(2)'])
df4
# Out:
#            심한장애    안 심한장애
# 동별(2)
# 종로구    0.372069  0.627931
# 중구     0.349308  0.650692
# 용산구    0.358704  0.641296
# 성동구    0.341457  0.658543
# 광진구    0.354036  0.645964
# 동대문구   0.343923  0.656077
# 중랑구    0.369701  0.630299
# 성북구    0.347256  0.652744
# 강북구    0.372463  0.627537
# 도봉구    0.363072  0.636928
# 노원구    0.440678  0.559322
# 은평구    0.382745  0.617255
# 서대문구   0.360003  0.639997
# 마포구    0.380147  0.619853
# 양천구    0.361027  0.638973
# 강서구    0.422126  0.577874
# 구로구    0.358006  0.641994
# 금천구    0.355647  0.644353
# 영등포구   0.337565  0.662435
# 동작구    0.360755  0.639245
# 관악구    0.365395  0.634605
# 서초구    0.395880  0.604120
# 강남구    0.447569  0.552431
# 송파구    0.381558  0.618442
# 강동구    0.382776  0.617224

# %%
df_se=df1.join(df4)
df_se.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25 entries, 종로구 to 강동구
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   외부신체장애  25 non-null     float64
#  1   내부기관장애  25 non-null     float64
#  2   정신적장애   25 non-null     float64
#  3   심한장애    25 non-null     float64
#  4   안 심한장애  25 non-null     float64
# dtypes: float64(5)
# memory usage: 1.7+ KB

# %%
df_in = pd.read_csv('PDQCSV_29_20220820070127188.csv', encoding='cp949')
df_in=df_in[df_in['통계시도명']=='서울특별시']

df_in=df_in.drop(columns=['통계년월','통계시도명'])
df_in=df_in.rename(columns={'통계시군구명':'구별'})
df_in=df_in.set_index('구별')
df_se['장애인연금수급율']=df_in['수급비율']
df_se['장애인연금수급율']=df_se['장애인연금수급율'].apply(lambda x:x/100)
df_se
# Out:
#         외부신체장애    내부기관장애     정신적장애      심한장애    안 심한장애  장애인연금수급율
# 구별
# 종로구   0.803677  0.066790  0.129533  0.372069  0.627931    0.8295
# 중구    0.830848  0.066560  0.102591  0.349308  0.650692    0.6137
# 용산구   0.801457  0.076893  0.121650  0.358704  0.641296    0.5701
# 성동구   0.811680  0.073290  0.115030  0.341457  0.658543    0.6051
# 광진구   0.802008  0.073615  0.124378  0.354036  0.645964    0.5799
# 동대문구  0.821691  0.068566  0.109744  0.343923  0.656077    0.6434
# 중랑구   0.806750  0.073734  0.119517  0.369701  0.630299    0.7238
# 성북구   0.812162  0.070820  0.117018  0.347256  0.652744    0.6317
# 강북구   0.809888  0.067088  0.123024  0.372463  0.627537    0.7424
# 도봉구   0.800915  0.070065  0.129020  0.363072  0.636928    0.6788
# 노원구   0.777840  0.066384  0.155776  0.440678  0.559322    0.7677
# 은평구   0.777211  0.068395  0.154394  0.382745  0.617255    0.7285
# 서대문구  0.802209  0.076273  0.121517  0.360003  0.639997    0.6252
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn import cluster
from sklearn import mixture
from sklearn import datasets
from sklearn.cluster import KMeans
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import silhouette_samples, silhouette_score
from sklearn.decomposition import PCA

kmeans = KMeans(n_clusters = 5, init='k-means++', max_iter=100, random_state=0).fit(df_se)
df_se['cluster'] = kmeans.labels_
print(kmeans.labels_)
# Out:
# [1 2 0 0 0 2 1 2 1 2 3 1 2 2 2 3 2 2 0 0 2 0 4 0 2]

# %%
marker0_ind = df_se[df_se['cluster']==0].index
marker1_ind = df_se[df_se['cluster']==1].index
marker2_ind = df_se[df_se['cluster']==2].index
marker3_ind = df_se[df_se['cluster']==3].index
marker4_ind = df_se[df_se['cluster']==4].index

print(marker0_ind)
print(marker1_ind)
print(marker2_ind)
print(marker3_ind)
print(marker4_ind)
# Out:
# Index(['용산구', '성동구', '광진구', '영등포구', '동작구', '서초구', '송파구'], dtype='object', name='구별')
# Index(['종로구', '중랑구', '강북구', '은평구'], dtype='object', name='구별')
# Index(['중구', '동대문구', '성북구', '도봉구', '서대문구', '마포구', '양천구', '구로구', '금천구', '관악구',
#        '강동구'],
#       dtype='object', name='구별')
# Index(['노원구', '강서구'], dtype='object', name='구별')
# Index(['강남구'], dtype='object', name='구별')
