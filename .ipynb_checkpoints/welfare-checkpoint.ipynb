# %%
import pandas as pd

# %%
# import os
# a = os.listdir('./welfarelist')
# print(a)
# li = []
# for i in a:
#     df = pd.read_html(f'welfarelist/{i}')
#     df =df[0]
#     df= df.drop(index = len(df)-1)
#     li.append(df)
    
# li[0]

# %%
df = pd.read_html('welfarelist/Fcltlist_2022-8.xls')
df_el=df[0]
df_el=df_el.drop(index = len(df_el)-1)
df_el
# Out:
#                     시설명     시도  시군구 시설유형(대)    시설유형(중)   시설유형(소)           연락처
# 0             성북피해장애인쉼터      -    -     장애인          -         -             -
# 1        서울특별시 피해장애인 쉼터      -    -     장애인          -         -             -
# 2               효천성바오로집  서울특별시  강남구      노인   노인주거복지시설      양로시설   02-572-5701
# 3       서울시니어스타워(주)강남본부  서울특별시  강남구      노인   노인주거복지시설    노인복지주택  02-2223-3351
# 4               더시그넘하우스  서울특별시  강남구      노인   노인주거복지시설    노인복지주택     025764400
# ...                 ...    ...  ...     ...        ...       ...           ...
# 3793              혜명보육원  서울특별시  NaN      아동     아동복지시설    아동양육시설   02-802-0358
# 3794         서울SOS어린이마을  서울특별시  NaN      아동     아동복지시설    아동양육시설  02-2692-0253
# 3795  서울특별시립장애인영농직업재활시설  서울특별시  NaN     장애인  장애인직업재활시설  장애인보호작업장    0315724025
# 3796        서울시립영보정신요양원  서울특별시  NaN    정신보건     정신요양시설    정신요양시설  031-323-5703
# 3797           서울광역자활센터  서울특별시  NaN     저소득       자활시설    지역자활센터     023184140
#
# [3798 rows x 7 columns]

# %%
df_el[df_el['시군구']=='강서구']
# Out:
#                  시설명     시도  시군구 시설유형(대)    시설유형(중)                 시설유형(소)  \
# 479           쟌쥬강의 집  서울특별시  강서구      노인   노인주거복지시설                    양로시설
# 480  서울시니어스타워(주)강서본부  서울특별시  강서구      노인   노인주거복지시설                  노인복지주택
# 481            그레이스힐  서울특별시  강서구      노인   노인주거복지시설                  노인복지주택
# 482  서울시니어스타워(주)가양본부  서울특별시  강서구      노인   노인주거복지시설                  노인복지주택
# 483            선화요양원  서울특별시  강서구      노인   노인의료복지시설                  노인요양시설
# ..               ...    ...  ...     ...        ...                     ...
# 701            한남하우스  서울특별시  강서구   한부모가족  한부모가족복지시설     미혼모자가족복지시설(공동생활지원형)
# 702            한남하우스  서울특별시  강서구   한부모가족  한부모가족복지시설     미혼모자가족복지시설(공동생활지원형)
# 703          구세군 한아름  서울특별시  강서구   한부모가족  한부모가족복지시설       부자가족복지시설(공동생활지원형)
# 704            애란세움터  서울특별시  강서구   한부모가족  한부모가족복지시설  미혼모자가족복지시설(미혼모공동생활지원형)
# 705          강서구가족센터  서울특별시  강서구   다문화가족  다문화가족복지시설               다문화가족지원센터
#
#               연락처
# 479    0226022472
# 480  02-2659-1100
# 481  02-3660-1510
# 482  02-3660-7700
# 483    0226551888
# ..            ...
# 701    0226618805
# 702    0226618805
# 703  02-2691-8445
# 704   02-703-4406
# 705  02-2606-2037
#
# [227 rows x 7 columns]
