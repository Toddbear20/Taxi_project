# %%
import pandas as pd

# %%
# import os
# a = os.listdir('./welfarelist')
# print(a)
# li = []
# for i in a:
#     df = pd.read_html(f'welfarelist/{i}')
#     df =df[0]
#     df= df.drop(index = len(df)-1)
#     li.append(df)
    
# li[0]

# %%
df = pd.read_html('welfarelist/Fcltlist_2022-8.xls')
df_el=df[0]
df_el=df_el.drop(index = len(df_el)-1)
df_el
# Out:
#                     시설명     시도  시군구 시설유형(대)    시설유형(중)   시설유형(소)           연락처
# 0             성북피해장애인쉼터      -    -     장애인          -         -             -
# 1        서울특별시 피해장애인 쉼터      -    -     장애인          -         -             -
# 2               효천성바오로집  서울특별시  강남구      노인   노인주거복지시설      양로시설   02-572-5701
# 3       서울시니어스타워(주)강남본부  서울특별시  강남구      노인   노인주거복지시설    노인복지주택  02-2223-3351
# 4               더시그넘하우스  서울특별시  강남구      노인   노인주거복지시설    노인복지주택     025764400
# ...                 ...    ...  ...     ...        ...       ...           ...
# 3793              혜명보육원  서울특별시  NaN      아동     아동복지시설    아동양육시설   02-802-0358
# 3794         서울SOS어린이마을  서울특별시  NaN      아동     아동복지시설    아동양육시설  02-2692-0253
# 3795  서울특별시립장애인영농직업재활시설  서울특별시  NaN     장애인  장애인직업재활시설  장애인보호작업장    0315724025
# 3796        서울시립영보정신요양원  서울특별시  NaN    정신보건     정신요양시설    정신요양시설  031-323-5703
# 3797           서울광역자활센터  서울특별시  NaN     저소득       자활시설    지역자활센터     023184140
#
# [3798 rows x 7 columns]

# %%
df_wel =df_el[df_el['시설유형(대)']=='장애인']
df_wel[df_wel['시군구']=='중랑구']
# Out:
#                      시설명     시도  시군구 시설유형(대)      시설유형(중)    시설유형(소)  \
# 3762  시립중랑장애인단기거주시설 다운누리  서울특별시  중랑구     장애인      장애인거주시설  장애인단기거주시설
# 3763              동천하우스5  서울특별시  중랑구     장애인      장애인거주시설  장애인공동생활가정
# 3764          원광장애인종합복지관  서울특별시  중랑구     장애인  장애인지역사회재활시설     장애인복지관
# 3765         원광장애인주간보호시설  서울특별시  중랑구     장애인  장애인지역사회재활시설  장애인주간보호시설
# 3766           중랑구수어통역센터  서울특별시  중랑구     장애인  장애인지역사회재활시설     수화통역센터
# 3767                  소담  서울특별시  중랑구     장애인    장애인직업재활시설   장애인보호작업장
# 3768                새론앞길  서울특별시  중랑구     장애인    장애인직업재활시설   장애인보호작업장
# 3769          중랑구립직업재활센터  서울특별시  중랑구     장애인    장애인직업재활시설   장애인보호작업장
# 3770             원광보호작업장  서울특별시  중랑구     장애인    장애인직업재활시설   장애인보호작업장
# 3771                조은세상  서울특별시  중랑구     장애인    장애인직업재활시설   장애인보호작업장
# 3772               참좋은센터  서울특별시  중랑구     장애인    장애인직업재활시설   장애인보호작업장
# 3773                아름다운  서울특별시  중랑구     장애인    장애인직업재활시설   장애인보호작업장
#
#                연락처
# 3762     024342114
# 3763  02-6084-5582
# 3764   02)438-2691
# 3765   02-438-2691
# 3766  02-2208-1084
# 3767     024337152
# 3768    0262132777
# 3769   02-977-8291
# 3770   02-438-2605
# 3771   02-439-9593
# 3772   02-491-3773
# 3773   02-971-1767

# %%
df_ab
# Out:
#                   시설명     시도  시군구 시설유형(대)      시설유형(중)    시설유형(소)  \
# 621               H2빌  서울특별시  강서구     장애인      장애인거주시설  중증장애인거주시설
# 622             교남시냇가  서울특별시  강서구     장애인      장애인거주시설  중증장애인거주시설
# 623               우리집  서울특별시  강서구     장애인      장애인거주시설  장애인단기거주시설
# 624             로뎀하우스  서울특별시  강서구     장애인      장애인거주시설  장애인단기거주시설
# 625               선린원  서울특별시  강서구     장애인      장애인거주시설  장애인단기거주시설
# 626     성산푸른초장 단기보호시설  서울특별시  강서구     장애인      장애인거주시설  장애인단기거주시설
# 627            강서희망의집  서울특별시  강서구     장애인      장애인거주시설  장애인단기거주시설
#
# 652   02-2662-3491
# 653   02-2692-2614
# 654   02-2658-7556
# 655     0226623491
# 656   02-2663-0670
# 657     0226657273
# 658   02-2065-0993
# 659   02-3665-3831
# 660  070-7576-2706
# 661   02-2697-3880
# 662   02-2658-6594
# 663   02-2605-9286
# 664   02-3665-3831
# 665   02-3665-4474
# 666     0226612280
# 667     0226611366
# 668   02-2697-3880
# 669   031-958-8593
# 670   02-3665-3831
# 671     0220651591
# 672   02-3661-0362
# 673   02-2658-0700
# 674   02-3661-3402
# 675   02-2696-3113
# 676   02-2602-3199
# 677  070-8715-3650
# 678   02-3665-1547
# 679    07077929300
# 680   02-2603-2683

# %%
df_wel.drop_duplicates(inplace=True)
df_wel
# Out:
# C:\Users\sch014\AppData\Local\Temp\ipykernel_16440\2232938244.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_wel.drop_duplicates(inplace=True)
#                  시설명     시도  시군구 시설유형(대)    시설유형(중)                 시설유형(소)  \
# 479           쟌쥬강의 집  서울특별시  강서구      노인   노인주거복지시설                    양로시설
# 480  서울시니어스타워(주)강서본부  서울특별시  강서구      노인   노인주거복지시설                  노인복지주택
# 481            그레이스힐  서울특별시  강서구      노인   노인주거복지시설                  노인복지주택
# 482  서울시니어스타워(주)가양본부  서울특별시  강서구      노인   노인주거복지시설                  노인복지주택
# 483            선화요양원  서울특별시  강서구      노인   노인의료복지시설                  노인요양시설
# ..               ...    ...  ...     ...        ...                     ...
# 700             마음자리  서울특별시  강서구   한부모가족  한부모가족복지시설     미혼모자가족복지시설(기본생활지원형)
# 701            한남하우스  서울특별시  강서구   한부모가족  한부모가족복지시설     미혼모자가족복지시설(공동생활지원형)
# 703          구세군 한아름  서울특별시  강서구   한부모가족  한부모가족복지시설       부자가족복지시설(공동생활지원형)
# 704            애란세움터  서울특별시  강서구   한부모가족  한부모가족복지시설  미혼모자가족복지시설(미혼모공동생활지원형)
# 705          강서구가족센터  서울특별시  강서구   다문화가족  다문화가족복지시설               다문화가족지원센터
#
#               연락처
# 479    0226022472
# 480  02-2659-1100
# 481  02-3660-1510
# 482  02-3660-7700
# 483    0226551888
# ..            ...
# 700  02-2691-4365
# 701    0226618805
# 703  02-2691-8445
# 704   02-703-4406
# 705  02-2606-2037
#
# [226 rows x 7 columns]

# %%
df = pd.read_csv('서울시 사회복지시설 목록.csv', encoding='cp949')
# 강서구 = df[df['시군구명']=='강서구']
# 강서구.to_excel('강서구.xlsx')

# %%
# 중랑구 = df[df['시군구명']=='중랑구']
# 중랑구.to_excel('중랑구.xlsx')

# %%
# 은평구 = df[df['시군구명']=='은평구']
# 은평구.to_excel('은평구.xlsx')

# %%
# 노원구 = df[df['시군구명']=='노원구']
# 노원구.to_excel('노원구.xlsx')

# %%
# 관악구 = df[df['시군구명']=='관악구']
# 관악구.to_excel('관악구.xlsx')

# %%
df_ad = pd.read_excel('강서구은평구노원구장애인현황_map.xlsx')
df_ad
m = len(df_ad)

df_add = df_ad.iloc[:,4:]
df_ad['총합'] = df_add.sum(1)
df_ad
# Out:
#       국가     도시   구별      동별      지체    뇌병변    언어   지적장애   자폐성   정신장애      총합
# 37  대한민국  서울특별시  강서구  등촌2동   306.0   80.0   3.0   32.0  14.0   31.0   466.0
# 38  대한민국  서울특별시  강서구  등촌3동  1426.0  424.0  26.0  302.0  34.0  362.0  2574.0
# 39  대한민국  서울특별시  강서구  화곡본동   590.0  135.0  12.0  115.0  22.0   65.0   939.0
# 40  대한민국  서울특별시  강서구  화곡2동   325.0   65.0   4.0   41.0  18.0   27.0   480.0
# 41  대한민국  서울특별시  강서구  화곡3동   319.0   94.0  11.0   47.0  11.0   32.0   514.0
# 42  대한민국  서울특별시  강서구  화곡4동   445.0   95.0   8.0   56.0  16.0   43.0   663.0
# 43  대한민국  서울특별시  강서구  화곡6동   396.0   80.0   7.0  117.0  18.0   40.0   658.0
# 44  대한민국  서울특별시  강서구  화곡8동   446.0   98.0  14.0   68.0  12.0   40.0   678.0
# 45  대한민국  서울특별시  강서구  가양1동   371.0   70.0   3.0   47.0  20.0   15.0   526.0
# 46  대한민국  서울특별시  강서구  가양2동   904.0  275.0  17.0  203.0  19.0  275.0  1693.0
# 47  대한민국  서울특별시  강서구  가양3동   646.0  161.0  17.0  113.0  12.0  150.0  1099.0
# 48  대한민국  서울특별시  강서구  발산1동   695.0  145.0  14.0  103.0  23.0   39.0  1019.0
# 49  대한민국  서울특별시  강서구   공항동   561.0  128.0  14.0   99.0  20.0   49.0   871.0
# 50  대한민국  서울특별시  강서구  방화1동   782.0  162.0  19.0  106.0  29.0   42.0  1140.0
# 51  대한민국  서울특별시  강서구  방화2동   673.0  164.0  19.0  131.0  12.0   91.0  1090.0
# 52  대한민국  서울특별시  강서구  방화3동   869.0  205.0  16.0  126.0  13.0  142.0  1371.0
# 53  대한민국  서울특별시  강서구  화곡1동   916.0  192.0  17.0  105.0  30.0   89.0  1349.0
# 54  대한민국  서울특별시  강서구  우장산동   508.0  118.0  13.0   98.0  32.0   45.0   814.0

# %%
# 강서구 장애인 총합
gang.sum()
# Out:
# 국가      대한민국대한민국대한민국대한민국대한민국대한민국대한민국대한민국대한민국대한민국대한민국대한...
# 도시      서울특별시서울특별시서울특별시서울특별시서울특별시서울특별시서울특별시서울특별시서울특별시서...
# 구별      강서구강서구강서구강서구강서구강서구강서구강서구강서구강서구강서구강서구강서구강서구강서구강...
# 동별      염창동등촌1동등촌2동등촌3동화곡본동화곡2동화곡3동화곡4동화곡6동화곡8동가양1동가양2...
# 지체                                                11921.0
# 뇌병변                                                2857.0
# 언어                                                  252.0
# 지적장애                                               2036.0
# 자폐성                                                 401.0
# 정신장애                                               1614.0
# 총합                                                19081.0
# dtype: object

# %%
df_gang= pd.read_excel('강서구_map.xlsx')

# %%
# df_gang = df_gang.drop(columns='Unnamed: 0')
df_gang
# Out:
#                시설명   시설코드      시설종류명(시설유형) 시설종류상세명(시설종류) 자치구(시)구분 시설장명  \
# 0          천사노인요양원  A0007      (노인) 노인요양시설      노인의료복지시설      자치구  김샛별
# 1    강서구립봉제산노인복지센터  A0922  (노인) 노인복지관(소규모)      노인여가복지시설      자치구  서순애
# 2       우리모두데이케어센터  A1074    (노인) 재가노인복지시설      재가노인복지시설      자치구  김기철
# 3        한마음방문요양센터  A1153    (노인) 재가노인복지시설      재가노인복지시설      자치구  이은점
# 4      참사랑재가노인지원센터  A1193    (노인) 재가노인복지시설      재가노인복지시설      자치구  조병기
# ..             ...    ...              ...           ...      ...  ...
# 183     등촌9종합사회복지관  Z5116       (일반) 사회복지관      일반사회복지시설      자치구  김기철
# 184    방화11종합사회복지관  Z5139       (일반) 사회복지관      일반사회복지시설      자치구  김상진
# 185     방화2종합사회복지관  Z5140       (일반) 사회복지관      일반사회복지시설      자치구  김지연
# 186     방화6종합사회복지관  Z5141       (일반) 사회복지관      일반사회복지시설      자치구  김성미
# 187      강서구치매지원센터  Z5448  (노인) (기타)노인복지시설          노인기타      자치구  정지향
#
#             시군구코드 시군구명                                시설주소   Latitude  \
# 0    1.150000e+09  강서구             서울특별시 강서구 강서로45다길 30-22  37.546652
# 1    1.150000e+09  강서구               서울특별시 강서구 초록마을로15길 12  37.541569
# 2    1.150000e+09  강서구                서울특별시 강서구 화곡로63가길 92  37.561615
# 3    1.150000e+09  강서구         서울특별시 강서구 초록마을로14길 44 (화곡동)  37.540965
# 4    1.150000e+09  강서구                 서울특별시 강서구 곰달래로 852층  37.531166
# ..            ...  ...                                 ...        ...
# 183  1.150000e+09  강서구      서울특별시 강서구 화곡로 63가길 92등촌9단지아파트내  37.561533
# 184  1.150000e+09  강서구  서울특별시 강서구 개화동로 21길 4sh공사 11단지아파트 내  37.570372
# 185  1.150000e+09  강서구      서울특별시 강서구 방화대로48길 40방화2종합사회복지관  37.574809
# 186  1.150000e+09  강서구             서울특별시 강서구 금낭화로23길 25-0   37.578330
# 187  1.150000e+09  강서구         서울특별시 강서구 화곡로 371경향교회회관 3층   37.557284
#
#       Longitude
# 0    126.833777
# 1    126.851313
# 2    126.849782
# 3    126.848089
# 4    126.852460
# ..          ...
# 183  126.848800
# 184  126.803075
# 185  126.819513
# 186  126.811072
# 187  126.852482
#
# [188 rows x 11 columns]

# %%
df_ds.drop(columns='총복지시설수')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [17], in <cell line: 1>()
# ----> 1 df_ds.drop(columns='총복지시설수')
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
#    4817     """
#    4818     Drop specified labels from rows or columns.
#    4819
#    (...)
#    4952             weight  1.0     0.8
#    4953     """
# -> 4954     return super().drop(
#    4955         labels=labels,
#    4956         axis=axis,
#    4957         index=index,
#    4958         columns=columns,
#    4959         level=level,
#    4960         inplace=inplace,
#    4961         errors=errors,
#    4962     )
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:4267, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265 for axis, labels in axes.items():
#    4266     if labels is not None:
# -> 4267         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4269 if inplace:
#    4270     self._update_inplace(obj)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:4311, in NDFrame._drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4309         new_axis = axis.drop(labels, level=level, errors=errors)
#    4310     else:
# -> 4311         new_axis = axis.drop(labels, errors=errors)
#    4312     indexer = axis.get_indexer(new_axis)
#    4314 # Case for non-unique axis
#    4315 else:
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:6644, in Index.drop(self, labels, errors)
#    6642 if mask.any():
#    6643     if errors != "ignore":
# -> 6644         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6645     indexer = indexer[~mask]
#    6646 return self.delete(indexer)
#
# KeyError: "['총복지시설수'] not found in axis"

# %%
import pandas as pd
df_ds = pd.read_csv('장애인구별_final.csv')
df_ds = df_ds.drop(columns='Unnamed: 0')
li = []
for i in range(len(df_ds)):
    all_f = df_ds['장애인거주시설'][i]+df_ds['장애인지역사회재활시설'][i]+df_ds['장애인직업재활시설'][i]
    li.append(all_f)
df_ds['총복지시설'] = li
df_ds
# Out:
#       구별  총 장애인 수  총 발달장애인 수  장애인거주시설  장애인지역사회재활시설  장애인직업재활시설  거주시설_최대수용수  \
# 0    종로구     5929        506        5            5          3         150
# 1     중구     5634        371        2            8          1          60
# 2    용산구     7686        653        3            7          1          90
# 3    성동구    11284        891        4            5          4         120
# 4    광진구    12253        994        1            9          4          30
# 5   동대문구    15518       1070        1            4          4          30
# 6    중랑구    20357       1577        2            3          7          60
# 7    성북구    17382       1387        4            3          2         120
# 8    강북구    17395       1393       18            8          4         540
# 9    도봉구    15300       1306       12            8          3         360
# 10   노원구    26904       2714       22           28          9         660
# 11   은평구    21756       2192       16           12          8         480
# 12  서대문구    12311        979        7            9          3         210
# 13   마포구    12945       1073        8           12          4         240
# 14   양천구    17525       1510       11            8          4         330
# 15   강서구    28546       2437       29           17         12         870
# 16   구로구    18374       1552       12            8          8         360
# 17   금천구    11458        921        8            7          7         240
# 18  영등포구    14495       1092        7           12          3         210
# 19   동작구    14417       1124        7            9          4         210
# 20   관악구    20211       1639        9           11          5         270
# 21   서초구    10291       1025       11           13          6         330
# 22   강남구    15182       1635       24           22          9         720
# 23   송파구    20356       2227       20           17         13         600
# 24   강동구    18614       1917       19           17         12         570
#
#     발달장애인은_거주시설_최대수용수의_몇배  총복지시설
# 0                       3     13
# 1                       6     11
# 2                       7     11
# 3                       7     13
# 4                      33     14
# 5                      36      9
# 6                      26     12
# 7                      12      9
# 8                       3     30
# 9                       4     23
# 10                      4     59
# 11                      5     36
# 12                      5     19
# 13                      4     24
# 14                      5     23
# 15                      3     58
# 16                      4     28
# 17                      4     22
# 18                      5     22
# 19                      5     20
# 20                      6     25
# 21                      3     30
# 22                      2     55
# 23                      4     50
# 24                      3     48

# %%
lis = []
for i in range(len(df_ds)):
    all_d= df_ds['총복지시설'][i]/df_ds['총 발달장애인 수'][i]
    lis.append(all_d)
    
df_ds['총발달장애인대비총복지시설'] = lis
mean = df_ds['총발달장애인대비총복지시설'].describe()[1]
mean
df_ds
# Out:
#       구별  총 장애인 수  총 발달장애인 수  장애인거주시설  장애인지역사회재활시설  장애인직업재활시설  거주시설_최대수용수  \
# 0    종로구     5929        506        5            5          3         150
# 1     중구     5634        371        2            8          1          60
# 2    용산구     7686        653        3            7          1          90
# 3    성동구    11284        891        4            5          4         120
# 4    광진구    12253        994        1            9          4          30
# 5   동대문구    15518       1070        1            4          4          30
# 6    중랑구    20357       1577        2            3          7          60
# 7    성북구    17382       1387        4            3          2         120
# 8    강북구    17395       1393       18            8          4         540
# 9    도봉구    15300       1306       12            8          3         360
# 10   노원구    26904       2714       22           28          9         660
# 11   은평구    21756       2192       16           12          8         480
# 12  서대문구    12311        979        7            9          3         210
# 13   마포구    12945       1073        8           12          4         240
# 14   양천구    17525       1510       11            8          4         330
# 15   강서구    28546       2437       29           17         12         870
# 16   구로구    18374       1552       12            8          8         360
# 17   금천구    11458        921        8            7          7         240
# 18  영등포구    14495       1092        7           12          3         210
# 19   동작구    14417       1124        7            9          4         210
# 20   관악구    20211       1639        9           11          5         270
# 21   서초구    10291       1025       11           13          6         330
# 22   강남구    15182       1635       24           22          9         720
# 23   송파구    20356       2227       20           17         13         600
# 24   강동구    18614       1917       19           17         12         570
#
#     발달장애인은_거주시설_최대수용수의_몇배  총복지시설  총발달장애인대비총복지시설
# 0                       3     13       0.025692
# 1                       6     11       0.029650
# 2                       7     11       0.016845
# 3                       7     13       0.014590
# 4                      33     14       0.014085
# 5                      36      9       0.008411
# 6                      26     12       0.007609
# 7                      12      9       0.006489
# 8                       3     30       0.021536
# 9                       4     23       0.017611
# 10                      4     59       0.021739
# 11                      5     36       0.016423
# 12                      5     19       0.019408
# 13                      4     24       0.022367
# 14                      5     23       0.015232
# 15                      3     58       0.023800
# 16                      4     28       0.018041
# 17                      4     22       0.023887
# 18                      5     22       0.020147
# 19                      5     20       0.017794
# 20                      6     25       0.015253
# 21                      3     30       0.029268
# 22                      2     55       0.033639
# 23                      4     50       0.022452
# 24                      3     48       0.025039

# %%
df_ds['복지시설부족여부'] = df_ds['총발달장애인대비총복지시설']>mean
df_ds['복지시설부족여부'].replace({True : '충분', False : '부족'}, inplace = True)
# df_ds.drop(columns = '평균지표',inplace = True)
df= df_ds.sort_values('총발달장애인대비총복지시설')
df=df.reset_index()
df=df.drop(columns='index')
df
# Out:
#       구별  총 장애인 수  총 발달장애인 수  장애인거주시설  장애인지역사회재활시설  장애인직업재활시설  거주시설_최대수용수  \
# 0    성북구    17382       1387        4            3          2         120
# 1    중랑구    20357       1577        2            3          7          60
# 2   동대문구    15518       1070        1            4          4          30
# 3    광진구    12253        994        1            9          4          30
# 4    성동구    11284        891        4            5          4         120
# 5    양천구    17525       1510       11            8          4         330
# 6    관악구    20211       1639        9           11          5         270
# 7    은평구    21756       2192       16           12          8         480
# 8    용산구     7686        653        3            7          1          90
# 9    도봉구    15300       1306       12            8          3         360
# 10   동작구    14417       1124        7            9          4         210
# 11   구로구    18374       1552       12            8          8         360
# 12  서대문구    12311        979        7            9          3         210
# 13  영등포구    14495       1092        7           12          3         210
# 14   강북구    17395       1393       18            8          4         540
# 15   노원구    26904       2714       22           28          9         660
# 16   마포구    12945       1073        8           12          4         240
# 17   송파구    20356       2227       20           17         13         600
# 18   강서구    28546       2437       29           17         12         870
# 19   금천구    11458        921        8            7          7         240
# 20   강동구    18614       1917       19           17         12         570
# 21   종로구     5929        506        5            5          3         150
# 22   서초구    10291       1025       11           13          6         330
# 23    중구     5634        371        2            8          1          60
# 24   강남구    15182       1635       24           22          9         720
#
#     발달장애인은_거주시설_최대수용수의_몇배  총복지시설  총발달장애인대비총복지시설 복지시설부족여부
# 0                      12      9       0.006489       부족
# 1                      26     12       0.007609       부족
# 2                      36      9       0.008411       부족
# 3                      33     14       0.014085       부족
# 4                       7     13       0.014590       부족
# 5                       5     23       0.015232       부족
# 6                       6     25       0.015253       부족
# 7                       5     36       0.016423       부족
# 8                       7     11       0.016845       부족
# 9                       4     23       0.017611       부족
# 10                      5     20       0.017794       부족
# 11                      4     28       0.018041       부족
# 12                      5     19       0.019408       부족
# 13                      5     22       0.020147       충분
# 14                      3     30       0.021536       충분
# 15                      4     59       0.021739       충분
# 16                      4     24       0.022367       충분
# 17                      4     50       0.022452       충분
# 18                      3     58       0.023800       충분
# 19                      4     22       0.023887       충분
# 20                      3     48       0.025039       충분
# 21                      3     13       0.025692       충분
# 22                      3     30       0.029268       충분
# 23                      6     11       0.029650       충분
# 24                      2     55       0.033639       충분

# %%
from sklearn.preprocessing import scale
from sklearn.cluster import KMeans
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

disa = pd.DataFrame(data = df, columns=['총발달장애인대비총복지시설', '총 발달장애인 수'])
disa

kmeans = KMeans(n_clusters = 5, init='k-means++', max_iter=100, random_state=0).fit(disa)
disa['cluster'] = kmeans.labels_
print(kmeans.labels_)

pca = PCA(n_components=2)
pca_transformed = pca.fit_transform(disa)
print(pca_transformed)
disa['pca_x'] = pca_transformed[:,0]
disa['pca_y'] = pca_transformed[:,1]
disa
# Out:
# [3 3 0 0 0 3 3 1 4 3 0 3 0 0 3 2 0 1 2 0 1 4 0 4 3]
# [[ 1.95999934e+01  1.28009899e+00]
#  [ 2.09599993e+02  1.28108626e+00]
#  [-2.97399991e+02 -1.72154731e+00]
#  [-3.73399991e+02 -1.72194090e+00]
#  [-4.76399991e+02 -1.72247586e+00]
#  [ 1.42599993e+02  1.28073985e+00]
#  [ 2.71599993e+02  1.28140999e+00]
#  [ 8.24600004e+02 -7.15716931e-01]
#  [-7.14400012e+02  2.27628814e+00]
#  [-6.14000066e+01  1.27968060e+00]
#  [-2.43399991e+02 -1.72126476e+00]
#  [ 1.84599993e+02  1.28095864e+00]
#  [-3.88399991e+02 -1.72201767e+00]
#  [-2.75399991e+02 -1.72143049e+00]
#  [ 2.55999933e+01  1.28013340e+00]
#  [ 1.34660000e+03  2.86995929e-01]
#  [-2.94399991e+02 -1.72152871e+00]
#  [ 8.59600004e+02 -7.15533808e-01]
#  [ 1.06960000e+03  2.85557388e-01]
#  [-4.46399991e+02 -1.72231801e+00]
#  [ 5.49600004e+02 -7.17143668e-01]
#  [-8.61400012e+02  2.27552640e+00]
#  [-3.42399991e+02 -1.72177658e+00]
#  [-9.96400012e+02  2.27482595e+00]
#  [ 2.67599993e+02  1.28139318e+00]]
#     총발달장애인대비총복지시설  총 발달장애인 수  cluster        pca_x     pca_y
# 0        0.006489       1387        3    19.599993  1.280099
# 1        0.007609       1577        3   209.599993  1.281086
# 2        0.008411       1070        0  -297.399991 -1.721547
# 3        0.014085        994        0  -373.399991 -1.721941
# 4        0.014590        891        0  -476.399991 -1.722476
# 5        0.015232       1510        3   142.599993  1.280740
# 6        0.015253       1639        3   271.599993  1.281410
# 7        0.016423       2192        1   824.600004 -0.715717
# 8        0.016845        653        4  -714.400012  2.276288
# 9        0.017611       1306        3   -61.400007  1.279681
# 10       0.017794       1124        0  -243.399991 -1.721265
# 11       0.018041       1552        3   184.599993  1.280959
# 12       0.019408        979        0  -388.399991 -1.722018
# 13       0.020147       1092        0  -275.399991 -1.721430
# 14       0.021536       1393        3    25.599993  1.280133
# 15       0.021739       2714        2  1346.599999  0.286996
# 16       0.022367       1073        0  -294.399991 -1.721529
# 17       0.022452       2227        1   859.600004 -0.715534
# 18       0.023800       2437        2  1069.599999  0.285557
# 19       0.023887        921        0  -446.399991 -1.722318
# 20       0.025039       1917        1   549.600004 -0.717144
# 21       0.025692        506        4  -861.400012  2.275526
# 22       0.029268       1025        0  -342.399991 -1.721777
# 23       0.029650        371        4  -996.400012  2.274826
# 24       0.033639       1635        3   267.599993  1.281393

# %%
marker0_ind = disa[disa['cluster']==0].index
marker1_ind = disa[disa['cluster']==1].index
marker2_ind = disa[disa['cluster']==2].index
marker3_ind = disa[disa['cluster']==3].index
marker4_ind = disa[disa['cluster']==4].index


plt.scatter(x= disa.loc[marker0_ind, 'pca_x'], y = disa.loc[marker0_ind, 'pca_y'], marker = 'o')
plt.scatter(x= disa.loc[marker1_ind, 'pca_x'], y = disa.loc[marker1_ind, 'pca_y'], marker = 's')
plt.scatter(x= disa.loc[marker2_ind, 'pca_x'], y = disa.loc[marker2_ind, 'pca_y'], marker = '^')
plt.scatter(x= disa.loc[marker3_ind, 'pca_x'], y = disa.loc[marker3_ind, 'pca_y'], marker = 'o')
plt.scatter(x= disa.loc[marker4_ind, 'pca_x'], y = disa.loc[marker4_ind, 'pca_y'], marker = 's')

plt.xlabel('PCA1')
plt.ylabel('PCA2')

plt.show()

# %%
from sklearn.datasets import make_blobs

x, y = make_blobs(n_samples=200, n_features=2, centers=3, cluster_std=0.8, random_state = 0)

print(x.shape, y.shape)

unique, counts = np.unique(y, return_counts=True)
print(unique, counts)
# Out:
# (200, 2) (200,)
# [0 1 2] [67 67 66]

# %%
import pandas as pd

clusterDF = pd.DataFrame(data = x, columns=['ftr1','ftr2'])
clusterDF['target'] = y
clusterDF
# Out:
#          ftr1      ftr2  target
# 0   -1.692427  3.622025       2
# 1    0.697940  4.428867       0
# 2    1.100228  4.606317       0
# 3   -1.448724  3.384245       2
# 4    1.214861  5.364896       0
# ..        ...       ...     ...
# 195  2.956576  0.033718       1
# 196 -2.074113  4.245523       2
# 197  2.783411  1.151438       1
# 198  1.226724  3.620511       0
# 199  1.474790 -0.209028       1
#
# [200 rows x 3 columns]

# %%
df=pd.read_csv('장애인시설비율.csv')
df=df.sort_values('구별')
arr=df['총복지시설']/df['총 장애인 수']
arr #총복지시설 대비 총 장애인 수
# Out:
# 22    0.003623
# 24    0.002579
# 8     0.001725
# 15    0.002032
# 20    0.001237
# 4     0.001143
# 16    0.001524
# 17    0.001920
# 10    0.002193
# 9     0.001503
# 5     0.000580
# 19    0.001387
# 13    0.001854
# 12    0.001543
# 21    0.002915
# 3     0.001152
# 7     0.000518
# 23    0.002456
# 14    0.001312
# 18    0.001518
# 2     0.001431
# 11    0.001655
# 0     0.002193
# 1     0.001952
# 6     0.000589
# dtype: float64

# %%
import pandas as pd
df = pd.read_csv('PDQCSV_26_20220720070116155.csv', encoding='cp949')
df_so = df[(df['통계시도명']=='서울특별시')]
df_so
# Out:
#          통계년월  통계시도명 통계시군구명  연령 장애유형  등록장애인수
# 0      202206  서울특별시    종로구  91  뇌병변       5
# 1      202206  서울특별시    종로구  59   지체      50
# 2      202206  서울특별시    종로구  92  뇌병변       1
# 3      202206  서울특별시    종로구  93  뇌병변       7
# 4      202206  서울특별시    종로구  94  뇌병변       1
# ...       ...    ...    ...  ..  ...     ...
# 21512  202206  서울특별시    강동구  86  뇌병변      21
# 21513  202206  서울특별시    강동구  59   지체     210
# 21514  202206  서울특별시    강동구  87  뇌병변      16
# 21515  202206  서울특별시    강동구  88  뇌병변      13
# 21516  202206  서울특별시    강동구  89  뇌병변      10
#
# [21517 rows x 6 columns]

# %%
df_so['장애유형'].unique()
# Out:
# array(['뇌병변', '지체', '자폐성', '정신', '신장', '심장', '호흡기', '간', '안면', '장루.요루',
#        '뇌전증', '시각', '청각', '언어', '지적'], dtype=object)

# %%
def age(x):
    x = (x//10)*10
    return x

# %%
import warnings
warnings.filterwarnings('ignore')
df_so['연령대'] = df_so.연령.apply(age)
df_so[(df_so['통계시군구명']=='노원구')&(df_so['장애유형']=='지적')&(df_so['연령대']==20)]
# Out:
#         통계년월  통계시도명 통계시군구명  연령 장애유형  등록장애인수  연령대
# 8893  202206  서울특별시    노원구  20   지적      49   20
# 8894  202206  서울특별시    노원구  21   지적      57   20
# 8895  202206  서울특별시    노원구  22   지적      59   20
# 8896  202206  서울특별시    노원구  23   지적      62   20
# 8897  202206  서울특별시    노원구  24   지적      57   20
# 8898  202206  서울특별시    노원구  25   지적      75   20
# 8899  202206  서울특별시    노원구  26   지적      55   20
# 8901  202206  서울특별시    노원구  27   지적      47   20
# 8902  202206  서울특별시    노원구  28   지적      45   20
# 8903  202206  서울특별시    노원구  29   지적      49   20

# %%
for i in range(len(df)):
    if df['연령'][i] < 10:
        df['연령대'] == '유아'
    elif df['연령'][i] < 20:
        df['연령대'][i] == '10대'
    elif df['연령'][i] < 30:
        df['연령대'][i] == '20대'
    elif df['연령'][i] < 40:
        df['연령대'][i] == '30대'
    elif df['연령'][i] < 50:
        df['연령대'][i] = '40대'
    elif df['연령'][i] < 60:
        df['연령대'][i] == '50대'
    elif df['연령'][i] < 70:
        df['연령대'][i] == '60대'
    elif df['연령'][i] < 80:
        df['연령대'][i] == '70대'
    elif df['연령'][i] >= 80:
        df['연령대'][i] == '고령자'
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Anaconda3\envs\cakd7\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\Anaconda3\envs\cakd7\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\Anaconda3\envs\cakd7\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '연령대'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [41], in <cell line: 1>()
#      17     df['연령대'][i] == '70대'
#      18 elif df['연령'][i] >= 80:
# ---> 19     df['연령대'][i] == '고령자'
#
# File ~\Anaconda3\envs\cakd7\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~\Anaconda3\envs\cakd7\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: '연령대'

# %%
df2 = pd.read_csv('PDQCSV_24_20220720070038593.csv', encoding='cp949')
df_so2 = df2[(df2['통계시도명']=='서울특별시')&(df2['통계시군구명']=='노원구')]

# %%
df_so2
# Out:
#        통계년월  통계시도명 통계시군구명   장애유형  성별  등록장애인수
# 300  202206  서울특별시    노원구     지체  남자    6065
# 301  202206  서울특별시    노원구     청각  여자    1773
# 302  202206  서울특별시    노원구     언어  남자     163
# 303  202206  서울특별시    노원구     언어  여자      83
# 304  202206  서울특별시    노원구     지적  남자    1372
# 305  202206  서울특별시    노원구     지적  여자     943
# 306  202206  서울특별시    노원구    뇌병변  남자    1542
# 307  202206  서울특별시    노원구    뇌병변  여자    1197
# 308  202206  서울특별시    노원구    자폐성  남자     335
# 309  202206  서울특별시    노원구    자폐성  여자      74
# 310  202206  서울특별시    노원구     정신  남자     708
# 311  202206  서울특별시    노원구     정신  여자     771
# 312  202206  서울특별시    노원구     신장  남자     687
# 313  202206  서울특별시    노원구     신장  여자     460
# 314  202206  서울특별시    노원구     지체  여자    5131
# 315  202206  서울특별시    노원구     심장  남자      57
# 316  202206  서울특별시    노원구     심장  여자      28
# 317  202206  서울특별시    노원구    호흡기  남자     106
# 318  202206  서울특별시    노원구    호흡기  여자      47
# 319  202206  서울특별시    노원구      간  남자      80
# 320  202206  서울특별시    노원구     시각  남자    1494
# 321  202206  서울특별시    노원구      간  여자      35
# 322  202206  서울특별시    노원구     안면  남자      17
# 323  202206  서울특별시    노원구     안면  여자      16
# 324  202206  서울특별시    노원구  장루.요루  남자      98
# 325  202206  서울특별시    노원구  장루.요루  여자      81
# 326  202206  서울특별시    노원구    뇌전증  남자      54
# 327  202206  서울특별시    노원구    뇌전증  여자      52
# 328  202206  서울특별시    노원구     시각  여자    1201
# 329  202206  서울특별시    노원구     청각  남자    1875

# %%
import pandas as pd

df_wel = pd.read_excel('서울시_구별_장애인유형_계.xlsx')
df_wel['구별 총 장애인 수'] = df_wel.sum(axis= 1)
df_wel.columns
# Out:
# Index(['구별', '지체_계', '뇌병변_계', '시각_계', '청각_계', '언어_계', '지적장애_계', '자폐성_계',
#        '정신장애_계', '신장장애_계', '심장장애_계', '호흡기_계', '간_계', '안면_계', '장루요루_계', '뇌전증_계',
#        '구별 총 장애인 수'],
#       dtype='object')

# %%
df_wel.sort_values('구별',inplace=True)
sum_arr=df_wel['구별 총 장애인 수']
sum_arr
# Out:
# 22    15182.0
# 24    18614.0
# 8     17395.0
# 15    28546.0
# 20    20211.0
# 4     12253.0
# 16    18374.0
# 17    11458.0
# 10    26904.0
# 9     15300.0
# 5     15518.0
# 19    14417.0
# 13    12945.0
# 12    12311.0
# 21    10291.0
# 3     11284.0
# 7     17382.0
# 23    20356.0
# 14    17525.0
# 18    14495.0
# 2      7686.0
# 11    21756.0
# 0      5929.0
# 1      5634.0
# 6     20357.0
# Name: 구별 총 장애인 수, dtype: float64

# %%
df_w.columns
# Out:
# Index(['구별', '구별_지체비율', '구별_뇌병변비율', '구별_시각비율', '구별_청각비율', '구별_언어비율', '구별_지적비율',
#        '구별_자폐비율', '구별_정신장애비율', '구별_신장비율', '구별_심장비율', '구별_호흡기비율', '구별_간비율',
#        '구별_안면비율', '구별_장루요루비율', '구별_뇌전증비율'],
#       dtype='object')

# %%
df_w = pd.DataFrame(columns=['구별','구별_지체비율', '구별_뇌병변비율','구별_시각비율','구별_청각비율','구별_언어비율','구별_지적비율','구별_자폐비율','구별_정신장애비율','구별_신장비율','구별_심장비율','구별_호흡기비율','구별_간비율','구별_안면비율','구별_장루요루비율','구별_뇌전증비율'])

df_w['구별'] = df['구별']
df_w['구별_지체비율'] = df['지체_계']/df['구별 총 장애인 수']
df_w['구별_뇌병변비율'] = df['뇌병변_계']/df['구별 총 장애인 수']
df_w['구별_시각비율'] = df['시각_계']/df['구별 총 장애인 수']
df_w['구별_청각비율'] = df['청각_계']/df['구별 총 장애인 수']
df_w['구별_언어비율'] = df['언어_계']/df['구별 총 장애인 수']
df_w['구별_지적비율'] = df['지적장애_계']/df['구별 총 장애인 수']
df_w['구별_자폐비율'] = df['자폐성_계']/df['구별 총 장애인 수']
df_w['구별_정신장애비율'] = df['정신장애_계']/df['구별 총 장애인 수']
df_w['구별_신장비율'] = df['신장장애_계']/df['구별 총 장애인 수']
df_w['구별_심장비율'] = df['심장장애_계']/df['구별 총 장애인 수']
df_w['구별_호흡기비율'] = df['호흡기_계']/df['구별 총 장애인 수']
df_w['구별_간비율'] = df['간_계']/df['구별 총 장애인 수']
df_w['구별_안면비율'] = df['안면_계']/df['구별 총 장애인 수']
df_w['구별_장루요루비율'] = df['장루요루_계']/df['구별 총 장애인 수']
df_w['구별_뇌전증비율'] = df['뇌전증_계']/df['구별 총 장애인 수']



df_w = df_w.set_index('구별')
cluster0 = df_w.loc[['서초구', '강남구', '송파구']]
cluster1 = df_w.loc[['중구', '성동구', '광진구', '동대문구', '중랑구', '성북구']]
cluster2 = df_w.loc[['노원구', '은평구', '강서구']]
cluster3 = df_w.loc[['종로구', '용산구', '도봉구', '서대문구', '마포구', '관악구', '강동구']]
cluster4 = df_w.loc[['강북구', '양천구', '구로구', '금천구', '영등포구', '동작구']]

cluster1
# Out:
#        구별_지체비율  구별_뇌병변비율   구별_시각비율   구별_청각비율   구별_언어비율   구별_지적비율   구별_자폐비율  \
# 구별
# 중구    0.443379  0.100639  0.127263  0.152645  0.005680  0.052716  0.013135
# 성동구   0.448511  0.101205  0.100585  0.150744  0.009571  0.061680  0.017281
# 광진구   0.441933  0.097282  0.107076  0.147637  0.007345  0.065780  0.015343
# 동대문구  0.455278  0.102011  0.097693  0.156528  0.009022  0.057933  0.011019
# 중랑구   0.464951  0.102864  0.102864  0.126885  0.008498  0.064990  0.012477
# 성북구   0.438442  0.102865  0.110632  0.149580  0.009608  0.065528  0.014268
#
#       구별_정신장애비율   구별_신장비율   구별_심장비율  구별_호흡기비율    구별_간비율   구별_안면비율  구별_장루요루비율  \
# 구별
# 중구     0.036741  0.040114  0.002485  0.005325  0.007277  0.001242   0.007632
# 성동구    0.036069  0.043158  0.002836  0.007887  0.007533  0.001063   0.008153
# 광진구    0.043255  0.047907  0.003020  0.005386  0.005468  0.000735   0.008243
# 동대문구   0.040791  0.044593  0.001998  0.005284  0.006637  0.001160   0.007217
# 중랑구    0.042049  0.047748  0.002456  0.007074  0.004814  0.000688   0.007958
# 성북구    0.037222  0.046370  0.002071  0.005235  0.007364  0.001036   0.006961
#
#       구별_뇌전증비율
# 구별
# 중구    0.003727
# 성동구   0.003722
# 광진구   0.003591
# 동대문구  0.002835
# 중랑구   0.003684
# 성북구   0.002819

# %%
from sklearn.preprocessing import scale
from sklearn.cluster import KMeans
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA


kmeans = KMeans(n_clusters = 6, init='k-means++', max_iter=100, random_state=0).fit(df_w)
df_w['cluster'] = kmeans.labels_
print(kmeans.labels_)

# pca = PCA(n_components=2)
# pca_transformed = pca.fit_transform(df_s2)
# print(pca_transformed)
# df_s2['pca_x'] = pca_transformed[:,0]
# df_s2['pca_y'] = pca_transformed[:,1]
# df_s2

marker0_ind = df_w[df_w['cluster']==0].index
marker1_ind = df_w[df_w['cluster']==1].index
marker2_ind = df_w[df_w['cluster']==2].index
marker3_ind = df_w[df_w['cluster']==3].index
marker4_ind = df_w[df_w['cluster']==4].index
marker5_ind = df_w[df_w['cluster']==5].index



print(marker0_ind)
print(marker1_ind)
print(marker2_ind)
print(marker3_ind)
print(marker4_ind)
print(marker5_ind)
# Out:
# [0 1 0 3 3 3 3 3 2 0 5 5 0 0 2 5 2 2 2 2 0 4 1 4 4]
# Index(['종로구', '용산구', '도봉구', '서대문구', '마포구', '관악구'], dtype='object', name='구별')
# Index(['중구', '강남구'], dtype='object', name='구별')
# Index(['강북구', '양천구', '구로구', '금천구', '영등포구', '동작구'], dtype='object', name='구별')
# Index(['성동구', '광진구', '동대문구', '중랑구', '성북구'], dtype='object', name='구별')
# Index(['서초구', '송파구', '강동구'], dtype='object', name='구별')
# Index(['노원구', '은평구', '강서구'], dtype='object', name='구별')

# %%
df_s = pd.read_excel('서울시_구별_성별_장애인유형.xlsx')
df_s2 = df_s.set_index('구별')
df_s2.columns
# Out:
# Index(['지체_남자', '지체_여자', '뇌병변_남자', '뇌병변_여자', '시각_남자', '시각_여자', '청각_남자',
#        '청각_여자', '언어_남자', '언어_여자', '지적장애_남자', '지적장애_여자', '자폐성_남자', '자폐성_여자',
#        '정신장애_남자', '정신장애_여자', '신장장애_남자', '신장장애_여자', '심장장애_남자', '심장장애_여자',
#        '호흡기_남자', '호흡기_여자', '간_남자', '간_여자', '안면_남자', '안면_여자', '장루요루_남자',
#        '장루요루_여자', '뇌전증_남자', '뇌전증_여자'],
#       dtype='object')

# %%
for i in range(25):
    df_s2.iloc[i]=df_s2.iloc[i].map(lambda x: x/df['구별 총 장애인 수'][i])

df_s2
# Out:
#          지체_남자     지체_여자    뇌병변_남자    뇌병변_여자     시각_남자     시각_여자     청각_남자  \
# 구별
# 종로구   0.231068  0.191938  0.058357  0.034913  0.074549  0.044021  0.088885
# 중구    0.241747  0.201633  0.066028  0.034611  0.078097  0.049166  0.085020
# 용산구   0.231330  0.191907  0.058418  0.040073  0.074291  0.047099  0.081577
# 성동구   0.252038  0.196473  0.061326  0.039879  0.057781  0.042804  0.080911
# 광진구   0.246389  0.195544  0.055741  0.041541  0.065943  0.041133  0.084877
# 동대문구  0.254285  0.200992  0.060704  0.041307  0.061348  0.036345  0.086674
# 중랑구   0.262514  0.202437  0.060471  0.042393  0.061257  0.041607  0.072211
# 성북구   0.240996  0.197446  0.059947  0.042918  0.065643  0.044989  0.083420
# 강북구   0.241621  0.191722  0.058580  0.039954  0.061339  0.048405  0.090658
# 도봉구   0.241307  0.187320  0.062876  0.045033  0.063595  0.041242  0.082680
# 강남구   0.064155  0.006060  0.002371  ...  0.004611  0.001647  0.006718
# 송파구   0.063470  0.006042  0.002604  ...  0.003881  0.001523  0.007467
# 강동구   0.060223  0.007897  0.003062  ...  0.003814  0.000967  0.004835
#
#           간_여자     안면_남자     안면_여자   장루요루_남자   장루요루_여자    뇌전증_남자    뇌전증_여자
# 구별
# 종로구   0.002193  0.000675  0.000506  0.003205  0.001855  0.001349  0.001349
# 중구    0.001775  0.000532  0.000710  0.005147  0.002485  0.002130  0.001597
# 용산구   0.001431  0.000520  0.000130  0.005725  0.003513  0.002082  0.000781
# 성동구   0.002570  0.000709  0.000354  0.004874  0.003279  0.002127  0.001595
# 광진구   0.001469  0.000408  0.000326  0.006203  0.002040  0.002204  0.001387
# 동대문구  0.002513  0.000644  0.000516  0.004189  0.003029  0.001482  0.001353
# 중랑구   0.001818  0.000246  0.000442  0.005011  0.002947  0.001768  0.001916
# 성북구   0.002646  0.000460  0.000575  0.004315  0.002646  0.001438  0.001381
# 강북구   0.001782  0.000115  0.000230  0.005059  0.002644  0.001782  0.001265
# 도봉구   0.002353  0.000654  0.000392  0.004967  0.003203  0.001765  0.000784
# 노원구   0.001301  0.000669  0.000595  0.003680  0.002862  0.001933  0.001970
# 은평구   0.002482  0.000552  0.000506  0.005608  0.003309  0.001655  0.001517
# 서대문구  0.002681  0.000325  0.000325  0.005117  0.004143  0.001300  0.001056
# 마포구   0.002008  0.000541  0.000386  0.006103  0.003399  0.001622  0.001236
# 양천구   0.002853  0.000399  0.000456  0.004051  0.002853  0.001541  0.001027
# 강서구   0.001752  0.000560  0.000490  0.004239  0.002102  0.002347  0.002102
# 구로구   0.001469  0.000871  0.000544  0.004735  0.002558  0.001306  0.001415
# 금천구   0.001833  0.000785  0.000698  0.003927  0.004015  0.002531  0.001222
# 영등포구  0.001656  0.001035  0.000483  0.004829  0.003174  0.001449  0.000966
# 동작구   0.002150  0.000486  0.000208  0.005272  0.002983  0.001665  0.001665
# 관악구   0.001583  0.000495  0.000247  0.003958  0.002870  0.001633  0.000990
# 서초구   0.003401  0.000194  0.000097  0.005150  0.003887  0.001263  0.001166
# 강남구   0.003030  0.000593  0.000659  0.004150  0.001251  0.001778  0.001844
# 송파구   0.002505  0.000491  0.000246  0.004520  0.002898  0.001916  0.001032
# 강동구   0.002310  0.000484  0.000591  0.004298  0.002955  0.001558  0.001773
#
# [25 rows x 30 columns]

# %%
from sklearn.preprocessing import scale
from sklearn.cluster import KMeans
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA


kmeans = KMeans(n_clusters = 5, init='k-means++', max_iter=100, random_state=0).fit(df_s2)
df_s2['cluster'] = kmeans.labels_
print(kmeans.labels_)

# pca = PCA(n_components=2)
# pca_transformed = pca.fit_transform(df_s2)
# print(pca_transformed)
# df_s2['pca_x'] = pca_transformed[:,0]
# df_s2['pca_y'] = pca_transformed[:,1]
# df_s2

marker0_ind = df_s2[df_s2['cluster']==0].index
marker1_ind = df_s2[df_s2['cluster']==1].index
marker2_ind = df_s2[df_s2['cluster']==2].index
marker3_ind = df_s2[df_s2['cluster']==3].index
marker4_ind = df_s2[df_s2['cluster']==4].index

print(marker0_ind)
print(marker1_ind)
print(marker2_ind)
print(marker3_ind)
print(marker4_ind)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [166], in <cell line: 9>()
#       5 import matplotlib.pyplot as plt
#       6 from sklearn.decomposition import PCA
# ----> 9 kmeans = KMeans(n_clusters = 5, init='k-means++', max_iter=100, random_state=0).fit(df_s2)
#      10 df_s2['cluster'] = kmeans.labels_
#      11 print(kmeans.labels_)
#
# NameError: name 'df_s2' is not defined

# %%
marker0_ind = df_s2[df_s2['cluster']==0].index
marker1_ind = df_s2[df_s2['cluster']==1].index
marker2_ind = df_s2[df_s2['cluster']==2].index
marker3_ind = df_s2[df_s2['cluster']==3].index
marker4_ind = df_s2[df_s2['cluster']==4].index


# plt.scatter(x= df_s2.loc[marker0_ind, 'pca_x'], y = df_s2.loc[marker0_ind, 'pca_y'], marker = 'o')
# plt.scatter(x= df_s2.loc[marker1_ind, 'pca_x'], y = df_s2.loc[marker1_ind, 'pca_y'], marker = 's')
# plt.scatter(x= df_s2.loc[marker2_ind, 'pca_x'], y = df_s2.loc[marker2_ind, 'pca_y'], marker = '^')
# plt.scatter(x= df_s2.loc[marker3_ind, 'pca_x'], y = df_s2.loc[marker3_ind, 'pca_y'], marker = 'o')
# plt.scatter(x= df_s2.loc[marker4_ind, 'pca_x'], y = df_s2.loc[marker4_ind, 'pca_y'], marker = 's')

# plt.xlabel('PCA1')
# plt.ylabel('PCA2')

# plt.show()

# %%
df = pd.read_csv('보건복지부_장애인복지관 현황_20191231.csv', encoding = 'cp949')

df[df['시도']=='서울']
# Out:
#     연번  시도   시군구 시설유형                  법인현황             시설명  \
# 0    1  서울   강남구  복지관                하상복지재단        강남장애인복지관
# 1    2  서울   강남구  복지관               자애종합복지원         성모자애복지관
# 2    3  서울   강남구  복지관            한국청각장애인복지회           청음복지관
# 3    4  서울   강남구  복지관                충현복지재단           충현복지관
# 4    5  서울   강남구  복지관                하상복지재단        하상장애인복지관
# 5    6  서울   강동구  복지관                   푸르메        서울장애인복지관
# 6    7  서울   강동구  복지관            부산성베네딕도수녀회          성분도복지관
# 7    8  서울   강동구  복지관               홀트아동복지회         홀트강동복지관
# 8    9  서울   강동구  복지관           한국시각장애인복지재단      한국시각장애인복지관
# 9   10  서울   강북구  복지관         대한불교조계종사회복지재단      강북장애인종합복지관
# 10  11  서울   강서구  복지관             한국뇌성마비복지회       강서뇌성마비복지관
# 11  12  서울   강서구  복지관                기쁜우리월드         기쁜우리복지관
# 12  13  서울   강서구  복지관          사회복지법인성요한복지회        늘푸른나무복지관
# 13  14  서울   관악구  복지관   대한예수교장로회실로암시각장애인복지회     실로암시각장애인복지관
# 14  15  서울   관악구  복지관             사회복지법인승가원     관악구장애인종합복지관
# 15  16  서울   광진구  복지관              한국소아마비협회            정립회관
# 16  17  서울   구로구  복지관                에덴복지재단      에덴장애인종합복지관
# 17  18  서울   구로구  복지관          (재)성프란치스코수녀회  성프란치스꼬장애인종합복지관
# 18  19  서울   금천구  복지관              사회복지법인상금      금천장애인종합복지관
# 19  20  서울   노원구  복지관            한국시각장애인연합회    서울노원시각장애인복지관
# 20  21  서울   노원구  복지관             한국뇌성마비복지회     서울시립뇌성마비복지관
# 21  22  서울   노원구  복지관                   다운회           다운복지관
# 22  23  서울   노원구  복지관             한국지체장애인협회      북부장애인종합복지관
# 23  24  서울   노원구  복지관             대한민국상이군경회     서울시립상이군경복지관
# 24  25  서울   노원구  복지관                    성민           성민복지관
# 25  26  서울   도봉구  복지관             한국장로교복지재단      도봉장애인종합복지관
# 26  27  서울  동대문구  복지관                동안복지재단   구립동대문장애인종합복지관
# 27  28  서울  동대문구  복지관  제칠일안식일예수재림교한국연합회유지재단        동문장애인복지관
# 28  29  서울   동작구  복지관             사회복지법인SRC    시립남부장애인종합복지관
# 29  30  서울   동작구  복지관         한국지적발달장애인복지협회      시립발달장애인복지관
# 30  31  서울   동작구  복지관           사회복지법인서울삼성원        삼성소리샘복지관
# 31  32  서울   마포구  복지관             감리회태화복지재단      마포장애인종합복지관
# 32  33  서울  서대문구  복지관               한국농아인협회     시립서대문농아인복지관
# 33  34  서울  서대문구  복지관          사회복지법인한국재활재단     서대문장애인종합복지관
# 34  35  서울   서초구  복지관               사랑의복지재단          사랑의복지관
# 35  36  서울   서초구  복지관            서울가톨릭사회복지회   서초구립한우리정보문화센터
# 36  37  서울   성동구  복지관               성모성심수도회      성동장애인종합복지관
# 37  38  서울   성북구  복지관               대한맹인복지회      성북시각장애인복지관
# 38  39  서울   성북구  복지관                   승가원        성북장애인복지관
# 39  40  서울   송파구  복지관      재단법인기독교대한감리회유지재단           방이복지관
# 40  41  서울   송파구  복지관                선한목자재단      서울시각장애인복지관
# 41  42  서울   송파구  복지관                다산복지재단      송파인성장애인복지관
# 42  43  서울   양천구  복지관   대한예수교장로회총회(합동측)복지재단      양천장애인종합복지관
# 43  44  서울  영등포구  복지관         대한불교조계종사회복지재단     시립영등포장애인복지관
# 44  45  서울   용산구  복지관             대한성공회유지재단      구립용산장애인복지관
# 45  46  서울   은평구  복지관                엔젤스헤이븐      서부장애인종합복지관
# 46  47  서울   종로구  복지관               재단법인푸르메        종로장애인복지관
# 47  48  서울    중구  복지관            서울가톨릭사회복지회   서울특별시중구장애인복지관
# 48  49  서울   중랑구  복지관          사회복지법인유린보은동산      원광장애인종합복지관
#
#                            시설 주소          전화번호          팩스번호  종사자정원  종사자 현원  \
# 0                서울시 강남구 개포로 605   02-445-8006   02-445-7010     31      31
# 1            서울시 강남구 헌릉로 757길 35  02-3411-9581  02-3411-9584     48      48
# 2             서울시 강남구 봉은사로 50길 6   02-556-3493   02-555-4241     37      37
# 3             서울시 강남구 논현로 98길 16  02-2192-0600  02-2192-0696     40      50
# 4                서울시 강남구 개포로 613   02-451-6000   02-459-4377     36      36
# 5           서울시 강동구 고덕로 201(고덕동)   02-440-5700   02-440-5780     89      89
# 6        경기도 광주시 도척면 국사봉로 159-10  031-799-0303  031-762-7285     30      31
# 7             서울시 강동구 아리수로93길 41  02-2251-6100  02-2251-6138     30      29
# 8          서울시 강동구 구천면로 645(상일동)   02-440-5200   02-440-5219     41      41
# 9                서울시 강북구 오현로 189   02-989-4214   02-989-4219     28      28
# 48                 서울시 중랑구 신내로56   02-438-2691   02-438-2695     36      42
#
#        엑스(X)좌표    와이(Y)좌표
# 0   127.073472  37.491983
# 1   127.119432  37.470582
# 2   127.042367  37.509378
# 3   127.037067  37.503703
# 4   127.075127  37.492554
# 5   127.148544  37.556206
# 6   127.349054  37.316034
# 7   127.173266  37.566221
# 8   127.169245  37.551109
# 9   127.039072  37.628757
# 10  126.812578  37.574204
# 11  126.848674  37.569390
# 12  126.851098  37.568548
# 13  126.941100  37.482942
# 14  126.961856  37.477441
# 15  127.097919  37.550533
# 16  126.841205  37.501180
# 17  126.890563  37.481804
# 18  126.896332  37.463972
# 19  127.056487  37.642071
# 20  127.056572  37.642495
# 21  127.080306  37.618940
# 22  127.056968  37.642534
# 23  127.057633  37.642819
# 24  127.069338  37.655625
# 25  127.047651  37.669427
# 26  127.034053  37.571816
# 27  127.073194  37.583149
# 28  126.918917  37.495384
# 29  126.918917  37.495384
# 30  126.946672  37.499193
# 31  126.908442  37.564019
# 32  126.913801  37.570700
# 33  126.957042  37.559475
# 34  127.023998  37.499838
# 35  127.025009  37.482051
# 36  127.033439  37.570225
# 37  127.019231  37.595391
# 38  127.045725  37.604600
# 39  127.114187  37.514650
# 40  127.094064  37.506117
# 41  127.155177  37.493892
# 42  126.869909  37.519893
# 43  126.912905  37.520855
# 44  126.961568  37.547306
# 45  126.906340  37.605645
# 46  126.969970  37.584024
# 47  127.022786  37.565091
# 48  127.095921  37.604472

# %%
import pandas as pd
import re

df = pd.read_csv('한국장애인고용공단_장애인 취업 정보_20201231.csv',encoding='cp949')
df
# Out:
#           순번        취업일자  연령  장애유형 중증여부        근무지역             취업직종대분류
# 0          1  2020-01-01  65  시각장애   중증      경북 경산시           경영·행정·사무직
# 1          2  2020-01-01  61  시각장애   중증      경북 고령군           경영·행정·사무직
# 2          3  2020-01-01  53  시각장애   경증      경북 의성군           경영·행정·사무직
# 3          4  2020-01-01  64  시각장애   중증      경북 성주군           경영·행정·사무직
# 4          5  2020-01-01  53  시각장애   경증      경북 군위군           경영·행정·사무직
# ...      ...         ...  ..   ...  ...         ...                 ...
# 31641  31642  2020-10-01  63  시각장애   경증      경기 광주시           경영·행정·사무직
# 31642  31643  2020-12-14  59  지체장애   경증  충남 천안시 동남구      돌봄 서비스직(간병·육아)
# 31643  31644  2020-12-03  53  시각장애   경증      서울 구로구              영업·판매직
# 31644  31645  2020-12-01  61  신장장애   중증     부산 해운대구  정보통신 연구개발직 및 공학기술직
# 31645  31646  2020-12-21  24  청각장애   경증       서울 중구             음식 서비스직
#
# [31646 rows x 7 columns]

# %%
df['근무지역_구별'] = df.근무지역.str.extract('서울\s([가-힣]+)')
df.dropna(inplace=True)
df
# Out:
#           순번        취업일자  연령  장애유형 중증여부    근무지역                  취업직종대분류  \
# 171      172  2020-10-19  30  지체장애   중증  서울 송파구                경영·행정·사무직
# 172      173  2020-10-19  23  지적장애   중증  서울 송파구                경영·행정·사무직
# 173      174  2020-10-19  32  정신장애   중증  서울 송파구                경영·행정·사무직
# 179      180  2020-12-14  20  청각장애   중증  서울 강남구              스포츠·레크리에이션직
# 180      181  2020-12-14  36  지체장애   중증  서울 강남구              스포츠·레크리에이션직
# ...      ...         ...  ..   ...  ...     ...                      ...
# 31617  31618  2020-06-09  22  언어장애   경증  서울 종로구  인쇄·목재·공예 및 기타 설치·정비·생산직
# 31618  31619  2020-01-30  70  지체장애   경증  서울 광진구  인쇄·목재·공예 및 기타 설치·정비·생산직
# 31621  31622  2020-11-23  53  지체장애   경증  서울 구로구                 사회복지·종교직
# 31643  31644  2020-12-03  53  시각장애   경증  서울 구로구                   영업·판매직
# 31645  31646  2020-12-21  24  청각장애   경증   서울 중구                  음식 서비스직
#
#       근무지역_구별
# 171       송파구
# 172       송파구
# 173       송파구
# 179       강남구
# 180       강남구
# ...       ...
# 31617     종로구
# 31618     광진구
# 31621     구로구
# 31643     구로구
# 31645      중구
#
# [7047 rows x 8 columns]

# %%
city_li = df['근무지역_구별'].unique()
city_li = city_li.tolist()

city_li = sorted(city_li)

li =[]
for i in city_li:
    city =df[df['근무지역_구별'] == i]
    li.append(len(city))
li
df_sort = pd.DataFrame(li)
df_sort=df_sort.set_index(df1['동별'])
df_sort
# Out:
#         0
# 동별
# 강남구   697
# 강동구   180
# 강북구    63
# 강서구   284
# 관악구   172
# 광진구   125
# 구로구   245
# 금천구   331
# 노원구   107
# 도봉구    85
# 동대문구   81
# 동작구   160
# 마포구   477
# 서대문구   67
# 서초구   323
# 성동구   198
# 성북구   172
# 송파구   940
# 양천구   128
# 영등포구  669
# 용산구   172
# 은평구    94
# 종로구   514
# 중구    638
# 중랑구   125

# %%
df1 = pd.read_csv('handicapped_df.csv')
df1=df1.drop(columns=['Unnamed: 0'])

# %%
df1=df1.sort_values('동별')
df1
# Out:
#       동별  연도별 평균 증감율  장애인연금_대상자에서수급자비율  연금 미수급자중 시설 필요자 수  심한장애중_장애인연금_대상자비율  \
# 22   강남구        -0.7              0.64                 57               0.56
# 24   강동구         1.4              0.63                 60               0.54
# 8    강북구         0.1              0.74                 38               0.54
# 15   강서구         0.2              0.76                 66               0.55
# 20   관악구         0.1              0.64                 56               0.51
# 4    광진구        -0.2              0.58                 38               0.50
# 16   구로구         1.3              0.65                 50               0.52
# 17   금천구         1.0              0.69                 28               0.52
# 10   노원구        -0.4              0.77                 65               0.56
# 9    도봉구         0.4              0.68                 40               0.53
# 5   동대문구        -0.5              0.64                 40               0.51
# 19   동작구        -0.3              0.60                 47               0.54
# 13   마포구        -0.7              0.62                 43               0.55
# 12  서대문구        -0.5              0.63                 36               0.52
# 21   서초구        -1.1              0.52                 42               0.52
# 3    성동구        -0.6              0.61                 32               0.51
# 7    성북구        -0.4              0.63                 50               0.53
# 23   송파구         0.9              0.58                 74               0.54
# 14   양천구         0.4              0.65                 47               0.52
# 18  영등포구         0.1              0.57                 46               0.53
# 2    용산구        -1.3              0.57                 25               0.50
# 11   은평구         0.4              0.73                 50               0.53
# 0    종로구        -0.5              0.83                  8               0.52
# 1     중구        -0.3              0.61                 17               0.52
# 6    중랑구         0.5              0.72                 46               0.53
#
#     심않장중_기초및차상위_비율
# 22            0.29
# 24            0.20
# 8             0.32
# 15            0.37
# 20            0.24
# 4             0.18
# 16            0.19
# 17            0.27
# 10            0.38
# 9             0.22
# 5             0.23
# 19            0.19
# 13            0.21
# 12            0.21
# 21            0.16
# 3             0.21
# 7             0.20
# 23            0.16
# 14            0.22
# 18            0.18
# 2             0.20
# 11            0.22
# 0             0.21
# 1             0.25
# 6             0.28

# %%
df_work = pd.read_csv('장애인취업률포함.csv')
df_work
df_work=df_work.set_index('동별')
df_work
# Out:
#       연도별 평균 증감율  장애인연금_대상자에서수급자비율  연금 미수급자중 시설 필요자 수  심한장애중_장애인연금_대상자비율  \
# 동별
# 강남구         -0.7              0.64                 57               0.56
# 강동구          1.4              0.63                 60               0.54
# 강북구          0.1              0.74                 38               0.54
# 강서구          0.2              0.76                 66               0.55
# 관악구          0.1              0.64                 56               0.51
# 광진구         -0.2              0.58                 38               0.50
# 구로구          1.3              0.65                 50               0.52
# 금천구          1.0              0.69                 28               0.52
# 노원구         -0.4              0.77                 65               0.56
# 도봉구          0.4              0.68                 40               0.53
# 동대문구        -0.5              0.64                 40               0.51
# 동작구         -0.3              0.60                 47               0.54
# 마포구         -0.7              0.62                 43               0.55
# 서대문구        -0.5              0.63                 36               0.52
# 서초구         -1.1              0.52                 42               0.52
# 성동구         -0.6              0.61                 32               0.51
# 성북구         -0.4              0.63                 50               0.53
# 송파구          0.9              0.58                 74               0.54
# 양천구          0.4              0.65                 47               0.52
# 영등포구         0.1              0.57                 46               0.53
# 용산구         -1.3              0.57                 25               0.50
# 은평구          0.4              0.73                 50               0.53
# 종로구         -0.5              0.83                  8               0.52
# 중구          -0.3              0.61                 17               0.52
# 중랑구          0.5              0.72                 46               0.53
#
#       심않장중_기초및차상위_비율    장애인취업률
# 동별
# 강남구             0.29  0.045910
# 강동구             0.20  0.009670
# 강북구             0.32  0.003622
# 강서구             0.37  0.009949
# 관악구             0.24  0.008510
# 광진구             0.18  0.010202
# 구로구             0.19  0.013334
# 금천구             0.27  0.028888
# 노원구             0.38  0.003977
# 도봉구             0.22  0.005556
# 동대문구            0.23  0.005220
# 동작구             0.19  0.011098
# 마포구             0.21  0.036848
# 서대문구            0.21  0.005442
# 서초구             0.16  0.031387
# 성동구             0.21  0.017547
# 성북구             0.20  0.009895
# 송파구             0.16  0.046178
# 양천구             0.22  0.007304
# 영등포구            0.18  0.046154
# 용산구             0.20  0.022378
# 은평구             0.22  0.004321
# 종로구             0.21  0.086693
# 중구              0.25  0.113241
# 중랑구             0.28  0.006140

# %%
# df1 = df1.rename(columns = {'구별 총 장애인 수':'장애인취업률'})
# df1
# df1.to_csv('장애인취업률포함.csv')
from sklearn.preprocessing import scale
from sklearn.cluster import KMeans
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.cluster import DBSCAN
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/gulim.ttc"
font = font_manager.FontProperties(fname = font_path).get_name()
rc('font', family = font)

kmeans = KMeans(n_clusters = 3, init='k-means++', max_iter=200, random_state=0).fit(df_work)
df_work['cluster'] = kmeans.labels_
print(kmeans.labels_)

marker0_ind = df_work[df_work['cluster']==0].index
marker1_ind = df_work[df_work['cluster']==1].index
marker2_ind = df_work[df_work['cluster']==2].index


print(marker0_ind)
print(marker1_ind)
print(marker2_ind)


sns.pairplot(df_work,hue='cluster')
plt.show()
# Out:
# [2 2 0 2 2 0 0 1 2 0 0 0 0 0 0 1 0 2 0 0 1 0 1 1 0]
# Index(['강북구', '광진구', '구로구', '도봉구', '동대문구', '동작구', '마포구', '서대문구', '서초구', '성북구',
#        '양천구', '영등포구', '은평구', '중랑구'],
#       dtype='object', name='동별')
# Index(['금천구', '성동구', '용산구', '종로구', '중구'], dtype='object', name='동별')
# Index(['강남구', '강동구', '강서구', '관악구', '노원구', '송파구'], dtype='object', name='동별')

# %%
df_work.columns
# Out:
# Index(['연도별 평균 증감율', '장애인연금_대상자에서수급자비율', '연금 미수급자중 시설 필요자 수',
#        '심한장애중_장애인연금_대상자비율', '심않장중_기초및차상위_비율', '장애인취업률', 'cluster'],
#       dtype='object')

# %%
inertia_list = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', random_state=0)
    kmeans.fit(df_work)
    inertia_list.append(kmeans.inertia_)
    
plt.plot(range(1, 11), inertia_list)
plt.title('Elbow Method')
plt.xlabel('n_clusters')
plt.ylabel('inertia')
plt.show()
# 클러스터가 3인 부분에서 기울기가 완만해짐
# 3개의 클러스터가 적절해보임

# %%
cluster0 = df_work[df_work['cluster']==0]
cluster1 = df_work[df_work['cluster']==1]
cluster2 = df_work[df_work['cluster']==2]

# %%
arr1=cluster0.mean()
arr1
# Out:
# 연도별 평균 증감율           -0.035714
# 장애인연금_대상자에서수급자비율      0.640000
# 연금 미수급자중 시설 필요자 수    43.785714
# 심한장애중_장애인연금_대상자비율     0.526429
# 심않장중_기초및차상위_비율        0.215000
# 장애인취업률                0.014037
# cluster               0.000000
# dtype: float64

# %%
arr2=cluster1.mean()

# %%
arr3=cluster2.mean()

# %%
clusters = pd.DataFrame(columns=['연도별 평균 증감율', '장애인연금_대상자에서수급자비율', '연금 미수급자중 시설 필요자 수',
       '심한장애중_장애인연금_대상자비율', '심않장중_기초및차상위_비율', '장애인취업률'],index = ['cluster_1','cluster_2','cluster_3'])

# %%
clusters.iloc[0] = arr1[0:6]
clusters.iloc[1] = arr2[0:6]
clusters.iloc[2] = arr3[0:6]

clusters
# Out:
#           연도별 평균 증감율 장애인연금_대상자에서수급자비율 연금 미수급자중 시설 필요자 수 심한장애중_장애인연금_대상자비율  \
# cluster_1  -0.035714             0.64         43.785714          0.526429
# cluster_2      -0.34            0.662              22.0             0.514
# cluster_3       0.25             0.67              63.0          0.543333
#
#           심않장중_기초및차상위_비율    장애인취업률
# cluster_1          0.215  0.014037
# cluster_2          0.228  0.053749
# cluster_3       0.273333  0.020699

# %%
import numpy as np
cluster1.describe()
# Out:
#        연도별 평균 증감율  장애인연금_대상자에서수급자비율  연금 미수급자중 시설 필요자 수  심한장애중_장애인연금_대상자비율  \
# count    3.000000          3.000000           3.000000              3.000
# mean    -0.300000          0.623333          28.333333              0.510
# std      1.178983          0.061101           3.511885              0.010
# min     -1.300000          0.570000          25.000000              0.500
# 25%     -0.950000          0.590000          26.500000              0.505
# 50%     -0.600000          0.610000          28.000000              0.510
# 75%      0.200000          0.650000          30.000000              0.515
# max      1.000000          0.690000          32.000000              0.520
#
#        심않장중_기초및차상위_비율    장애인취업률  장애아동수급비율
# count        3.000000  3.000000  3.000000
# mean         0.226667  0.022938  0.143333
# std          0.037859  0.005691  0.025166
# min          0.200000  0.017547  0.120000
# 25%          0.205000  0.019963  0.130000
# 50%          0.210000  0.022378  0.140000
# 75%          0.240000  0.025633  0.155000
# max          0.270000  0.028888  0.170000

# %%
df_work
# Out:
#       연도별 평균 증감율  장애인연금_대상자에서수급자비율  연금 미수급자중 시설 필요자 수  심한장애중_장애인연금_대상자비율  \
# 동별
# 강남구         -0.7              0.64                 57               0.56
# 강동구          1.4              0.63                 60               0.54
# 강북구          0.1              0.74                 38               0.54
# 강서구          0.2              0.76                 66               0.55
# 관악구          0.1              0.64                 56               0.51
# 광진구         -0.2              0.58                 38               0.50
# 구로구          1.3              0.65                 50               0.52
# 금천구          1.0              0.69                 28               0.52
# 노원구         -0.4              0.77                 65               0.56
# 도봉구          0.4              0.68                 40               0.53
# 동대문구        -0.5              0.64                 40               0.51
# 동작구         -0.3              0.60                 47               0.54
# 마포구         -0.7              0.62                 43               0.55
# 서대문구        -0.5              0.63                 36               0.52
# 서초구         -1.1              0.52                 42               0.52
# 성동구         -0.6              0.61                 32               0.51
# 성북구         -0.4              0.63                 50               0.53
# 송파구          0.9              0.58                 74               0.54
# 양천구          0.4              0.65                 47               0.52
# 영등포구         0.1              0.57                 46               0.53
# 용산구         -1.3              0.57                 25               0.50
# 은평구          0.4              0.73                 50               0.53
# 종로구         -0.5              0.83                  8               0.52
# 중구          -0.3              0.61                 17               0.52
# 중랑구          0.5              0.72                 46               0.53
#
#       심않장중_기초및차상위_비율    장애인취업률  cluster
# 동별
# 강남구             0.29  0.045910        2
# 강동구             0.20  0.009670        2
# 강북구             0.32  0.003622        0
# 강서구             0.37  0.009949        2
# 관악구             0.24  0.008510        2
# 광진구             0.18  0.010202        0
# 구로구             0.19  0.013334        0
# 금천구             0.27  0.028888        1
# 노원구             0.38  0.003977        2
# 도봉구             0.22  0.005556        0
# 동대문구            0.23  0.005220        0
# 동작구             0.19  0.011098        0
# 마포구             0.21  0.036848        0
# 서대문구            0.21  0.005442        0
# 서초구             0.16  0.031387        0
# 성동구             0.21  0.017547        1
# 성북구             0.20  0.009895        0
# 송파구             0.16  0.046178        2
# 양천구             0.22  0.007304        0
# 영등포구            0.18  0.046154        0
# 용산구             0.20  0.022378        1
# 은평구             0.22  0.004321        0
# 종로구             0.21  0.086693        1
# 중구              0.25  0.113241        1
# 중랑구             0.28  0.006140        0

# %%
df_work = df_work.drop(columns=['장애아동수급비율'])
df_work
# Out:
#       연도별 평균 증감율  장애인연금_대상자에서수급자비율  연금 미수급자중 시설 필요자 수  심한장애중_장애인연금_대상자비율  \
# 동별
# 강남구         -0.7              0.64                 57               0.56
# 강동구          1.4              0.63                 60               0.54
# 강북구          0.1              0.74                 38               0.54
# 강서구          0.2              0.76                 66               0.55
# 관악구          0.1              0.64                 56               0.51
# 광진구         -0.2              0.58                 38               0.50
# 구로구          1.3              0.65                 50               0.52
# 금천구          1.0              0.69                 28               0.52
# 노원구         -0.4              0.77                 65               0.56
# 도봉구          0.4              0.68                 40               0.53
# 동대문구        -0.5              0.64                 40               0.51
# 동작구         -0.3              0.60                 47               0.54
# 마포구         -0.7              0.62                 43               0.55
# 서대문구        -0.5              0.63                 36               0.52
# 서초구         -1.1              0.52                 42               0.52
# 성동구         -0.6              0.61                 32               0.51
# 성북구         -0.4              0.63                 50               0.53
# 송파구          0.9              0.58                 74               0.54
# 양천구          0.4              0.65                 47               0.52
# 영등포구         0.1              0.57                 46               0.53
# 용산구         -1.3              0.57                 25               0.50
# 은평구          0.4              0.73                 50               0.53
# 종로구         -0.5              0.83                  8               0.52
# 중구          -0.3              0.61                 17               0.52
# 중랑구          0.5              0.72                 46               0.53
#
#       심않장중_기초및차상위_비율    장애인취업률  cluster
# 동별
# 강남구             0.29  0.045910        2
# 강동구             0.20  0.009670        2
# 강북구             0.32  0.003622        0
# 강서구             0.37  0.009949        2
# 관악구             0.24  0.008510        2
# 광진구             0.18  0.010202        0
# 구로구             0.19  0.013334        0
# 금천구             0.27  0.028888        1
# 노원구             0.38  0.003977        2
# 도봉구             0.22  0.005556        0
# 동대문구            0.23  0.005220        0
# 동작구             0.19  0.011098        0
# 마포구             0.21  0.036848        0
# 서대문구            0.21  0.005442        0
# 서초구             0.16  0.031387        0
# 성동구             0.21  0.017547        1
# 성북구             0.20  0.009895        0
# 송파구             0.16  0.046178        2
# 양천구             0.22  0.007304        0
# 영등포구            0.18  0.046154        0
# 용산구             0.20  0.022378        1
# 은평구             0.22  0.004321        0
# 종로구             0.21  0.086693        1
# 중구              0.25  0.113241        1
# 중랑구             0.28  0.006140        0

# %%
df_work
# Out:
#       연도별 평균 증감율  장애인연금_대상자에서수급자비율  연금 미수급자중 시설 필요자 수  심한장애중_장애인연금_대상자비율  \
# 동별
# 강남구         -0.7              0.64                 57               0.56
# 강동구          1.4              0.63                 60               0.54
# 강북구          0.1              0.74                 38               0.54
# 강서구          0.2              0.76                 66               0.55
# 관악구          0.1              0.64                 56               0.51
# 광진구         -0.2              0.58                 38               0.50
# 구로구          1.3              0.65                 50               0.52
# 금천구          1.0              0.69                 28               0.52
# 노원구         -0.4              0.77                 65               0.56
# 도봉구          0.4              0.68                 40               0.53
# 동대문구        -0.5              0.64                 40               0.51
# 동작구         -0.3              0.60                 47               0.54
# 마포구         -0.7              0.62                 43               0.55
# 서대문구        -0.5              0.63                 36               0.52
# 서초구         -1.1              0.52                 42               0.52
# 성동구         -0.6              0.61                 32               0.51
# 성북구         -0.4              0.63                 50               0.53
# 송파구          0.9              0.58                 74               0.54
# 양천구          0.4              0.65                 47               0.52
# 영등포구         0.1              0.57                 46               0.53
# 용산구         -1.3              0.57                 25               0.50
# 은평구          0.4              0.73                 50               0.53
# 종로구         -0.5              0.83                  8               0.52
# 중구          -0.3              0.61                 17               0.52
# 중랑구          0.5              0.72                 46               0.53
#
#       심않장중_기초및차상위_비율    장애인취업률  cluster
# 동별
# 강남구             0.29  0.045910        2
# 강동구             0.20  0.009670        2
# 강북구             0.32  0.003622        0
# 강서구             0.37  0.009949        2
# 관악구             0.24  0.008510        2
# 광진구             0.18  0.010202        0
# 구로구             0.19  0.013334        0
# 금천구             0.27  0.028888        1
# 노원구             0.38  0.003977        2
# 도봉구             0.22  0.005556        0
# 동대문구            0.23  0.005220        0
# 동작구             0.19  0.011098        0
# 마포구             0.21  0.036848        0
# 서대문구            0.21  0.005442        0
# 서초구             0.16  0.031387        0
# 성동구             0.21  0.017547        1
# 성북구             0.20  0.009895        0
# 송파구             0.16  0.046178        2
# 양천구             0.22  0.007304        0
# 영등포구            0.18  0.046154        0
# 용산구             0.20  0.022378        1
# 은평구             0.22  0.004321        0
# 종로구             0.21  0.086693        1
# 중구              0.25  0.113241        1
# 중랑구             0.28  0.006140        0

# %%
df_child = pd.read_csv('child_handicapped_final.csv', index_col='통계시군구명')
df_work['장애아동수급비율'] = df_child['장애아동수급비율']
df_work['장애인대비복지시설'] = arr.to_list()
df.work=df_work.drop(columns = ['cluster'])
df.work
# Out:
#       연도별 평균 증감율  장애인연금_대상자에서수급자비율  연금 미수급자중 시설 필요자 수  심한장애중_장애인연금_대상자비율  \
# 동별
# 강남구         -0.7              0.64                 57               0.56
# 강동구          1.4              0.63                 60               0.54
# 강북구          0.1              0.74                 38               0.54
# 강서구          0.2              0.76                 66               0.55
# 관악구          0.1              0.64                 56               0.51
# 광진구         -0.2              0.58                 38               0.50
# 구로구          1.3              0.65                 50               0.52
# 금천구          1.0              0.69                 28               0.52
# 노원구         -0.4              0.77                 65               0.56
# 도봉구          0.4              0.68                 40               0.53
# 동대문구        -0.5              0.64                 40               0.51
# 동작구         -0.3              0.60                 47               0.54
# 마포구         -0.7              0.62                 43               0.55
# 서대문구        -0.5              0.63                 36               0.52
# 서초구         -1.1              0.52                 42               0.52
# 성동구         -0.6              0.61                 32               0.51
# 성북구         -0.4              0.63                 50               0.53
# 송파구          0.9              0.58                 74               0.54
# 양천구          0.4              0.65                 47               0.52
# 영등포구         0.1              0.57                 46               0.53
# 용산구         -1.3              0.57                 25               0.50
# 은평구          0.4              0.73                 50               0.53
# 종로구         -0.5              0.83                  8               0.52
# 중구          -0.3              0.61                 17               0.52
# 중랑구          0.5              0.72                 46               0.53
#
#       심않장중_기초및차상위_비율    장애인취업률  장애아동수급비율  장애인대비복지시설
# 동별
# 강남구             0.29  0.045910      0.07   0.003623
# 강동구             0.20  0.009670      0.12   0.002579
# 강북구             0.32  0.003622      0.18   0.001725
# 강서구             0.37  0.009949      0.14   0.002032
# 관악구             0.24  0.008510      0.20   0.001237
# 광진구             0.18  0.010202      0.13   0.001143
# 구로구             0.19  0.013334      0.12   0.001524
# 금천구             0.27  0.028888      0.17   0.001920
# 노원구             0.38  0.003977      0.17   0.002193
# 도봉구             0.22  0.005556      0.18   0.001503
# 동대문구            0.23  0.005220      0.18   0.000580
# 동작구             0.19  0.011098      0.10   0.001387
# 마포구             0.21  0.036848      0.10   0.001854
# 서대문구            0.21  0.005442      0.11   0.001543
# 서초구             0.16  0.031387      0.07   0.002915
# 성동구             0.21  0.017547      0.12   0.001152
# 성북구             0.20  0.009895      0.12   0.000518
# 송파구             0.16  0.046178      0.09   0.002456
# 양천구             0.22  0.007304      0.11   0.001312
# 영등포구            0.18  0.046154      0.08   0.001518
# 용산구             0.20  0.022378      0.14   0.001431
# 은평구             0.22  0.004321      0.15   0.001655
# 종로구             0.21  0.086693      0.12   0.002193
# 중구              0.25  0.113241      0.11   0.001952
# 중랑구             0.28  0.006140      0.19   0.000589

# %%
inertia_list = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', random_state=0)
    kmeans.fit(df_work)
    inertia_list.append(kmeans.inertia_)
    
plt.plot(range(1, 11), inertia_list)
plt.title('Elbow Method')
plt.xlabel('n_clusters')
plt.ylabel('inertia')
plt.show()
# 클러스터가 6인 부분에서 기울기가 완만해짐
# 6개의 클러스터가 적절해보임

# %%
from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/gulim.ttc"
font = font_manager.FontProperties(fname = font_path).get_name()
rc('font', family = font)

kmeans = KMeans(n_clusters = 4, init='k-means++', max_iter=200, random_state=0).fit(df_work)
df_work['cluster'] = kmeans.labels_
print(kmeans.labels_)

marker0_ind = df_work[df_work['cluster']==0].index
marker1_ind = df_work[df_work['cluster']==1].index
marker2_ind = df_work[df_work['cluster']==2].index
marker3_ind = df_work[df_work['cluster']==3].index




print(marker0_ind)
print(marker1_ind)
print(marker2_ind)
print(marker3_ind)




sns.pairplot(df_work,hue='cluster')
plt.show()
# Out:
# [2 2 1 2 2 1 0 3 2 1 1 0 1 1 1 1 0 2 0 0 3 0 3 3 0]
# Index(['구로구', '동작구', '성북구', '양천구', '영등포구', '은평구', '중랑구'], dtype='object', name='동별')
# Index(['강북구', '광진구', '도봉구', '동대문구', '마포구', '서대문구', '서초구', '성동구'], dtype='object', name='동별')
# Index(['강남구', '강동구', '강서구', '관악구', '노원구', '송파구'], dtype='object', name='동별')
# Index(['금천구', '용산구', '종로구', '중구'], dtype='object', name='동별')

# %%
cluster0 = df_work[df_work['cluster']==0]
cluster1 = df_work[df_work['cluster']==1]
cluster2 = df_work[df_work['cluster']==2]
cluster3 = df_work[df_work['cluster']==3]


cluster0=cluster0.drop(columns=['cluster'])
cluster1=cluster1.drop(columns=['cluster'])
cluster2=cluster2.drop(columns=['cluster'])
cluster3=cluster3.drop(columns=['cluster'])

# %%
clusters_ch = pd.DataFrame(columns=['연도별 평균 증감율', '장애인연금_대상자에서수급자비율', '연금 미수급자중 시설 필요자 수',
       '심한장애중_장애인연금_대상자비율', '심않장중_기초및차상위_비율', '장애인취업률', '장애아동수급비율','장애인대비복지시설'],index = ['cluster_1','cluster_2','cluster_3','cluster_4'])

# %%
clusters_ch
# Out:
#           연도별 평균 증감율 장애인연금_대상자에서수급자비율 연금 미수급자중 시설 필요자 수 심한장애중_장애인연금_대상자비율  \
# cluster_1        NaN              NaN               NaN               NaN
# cluster_2        NaN              NaN               NaN               NaN
# cluster_3        NaN              NaN               NaN               NaN
# cluster_4        NaN              NaN               NaN               NaN
#
#           심않장중_기초및차상위_비율 장애인취업률 장애아동수급비율 장애인대비복지시설
# cluster_1            NaN    NaN      NaN       NaN
# cluster_2            NaN    NaN      NaN       NaN
# cluster_3            NaN    NaN      NaN       NaN
# cluster_4            NaN    NaN      NaN       NaN

# %%
arr1=cluster0.mean()
arr2=cluster1.mean()
arr3=cluster2.mean()
arr4=cluster3.mean()

# %%
clusters_ch.iloc[0] = arr1
clusters_ch.iloc[1] = arr2
clusters_ch.iloc[2] = arr3
clusters_ch.iloc[3] = arr4

li = clusters_ch['연금 미수급자중 시설 필요자 수'].to_list()

lis = []
for i in li:
    lis.append(np.ceil(i))
    
clusters_ch['연금 미수급자중 시설 필요자 수'] = lis

clusters_ch
# Out:
#           연도별 평균 증감율 장애인연금_대상자에서수급자비율  연금 미수급자중 시설 필요자 수 심한장애중_장애인연금_대상자비율  \
# cluster_1   0.285714             0.65               48.0          0.528571
# cluster_2       -0.3         0.623333               29.0              0.51
# cluster_3   0.233333         0.703333               69.0              0.55
# cluster_4       -0.4             0.72               13.0              0.52
#
#           심않장중_기초및차상위_비율    장애인취업률  장애아동수급비율 장애인대비복지시설
# cluster_1       0.211429  0.014035  0.124286  0.001215
# cluster_2       0.226667  0.022938  0.143333  0.001501
# cluster_3       0.303333  0.020035  0.133333  0.002227
# cluster_4           0.23  0.099967     0.115  0.002073

# %%
import pandas as pd
df_age = pd.read_csv('PDQCSV_25_20220820070042273.csv', encoding='cp949')
df_age = df_age[df_age['통계시도명']=='서울특별시']
df_age = df_age[(df_age['장애정도']=='심한 장애')&(df_age['통계시군구명']=='강서구')]
df_age.sum()
# Out:
# 통계년월                                               20625114
# 통계시도명     서울특별시서울특별시서울특별시서울특별시서울특별시서울특별시서울특별시서울특별시서울특별시서...
# 통계시군구명    강서구강서구강서구강서구강서구강서구강서구강서구강서구강서구강서구강서구강서구강서구강서구강...
# 연령                                                     5363
# 장애정도      심한 장애심한 장애심한 장애심한 장애심한 장애심한 장애심한 장애심한 장애심한 장애심...
# 등록장애인수                                                11866
# dtype: object

# %%
# 장애인 취업자수
df_sort
# Out:
#         0
# 동별
# 강남구   697
# 강동구   180
# 강북구    63
# 강서구   284
# 관악구   172
# 광진구   125
# 구로구   245
# 금천구   331
# 노원구   107
# 도봉구    85
# 동대문구   81
# 동작구   160
# 마포구   477
# 서대문구   67
# 서초구   323
# 성동구   198
# 성북구   172
# 송파구   940
# 양천구   128
# 영등포구  669
# 용산구   172
# 은평구    94
# 종로구   514
# 중구    638
# 중랑구   125

# %%
df_dong = pd.read_csv('0825_장애인비율동별.csv')
df_jong=df_dong[df_dong['구']=='종로구']

df_jong['장애인취업자']=df_jong['비율']*(df_sort.loc['종로구'][0])
df_jong
# Out:
#     Unnamed: 0    구            동      계        비율     장애인취업자
# 0            2  종로구          사직동  277.0  0.046720  24.013830
# 1            3  종로구          삼청동  108.0  0.018216   9.362793
# 2            4  종로구          부암동  318.0  0.053635  27.568224
# 3            5  종로구          평창동  513.0  0.086524  44.473267
# 4            6  종로구          무악동  322.0  0.054309  27.914994
# 5            7  종로구          교남동  356.0  0.060044  30.862540
# 6            8  종로구          가회동  177.0  0.029853  15.344578
# 7            9  종로구  종로1.2.3.4가동  383.0  0.064598  33.203238
# 8           10  종로구      종로5.6가동  261.0  0.044021  22.626750
# 9           11  종로구          이화동  323.0  0.054478  28.001687
# 10          12  종로구         창신1동  285.0  0.048069  24.707371
# 11          13  종로구         창신2동  501.0  0.084500  43.432957
# 12          14  종로구         창신3동  336.0  0.056671  29.128689
# 13          15  종로구         숭인1동  289.0  0.048743  25.054141
# 14          16  종로구         숭인2동  422.0  0.071176  36.584247
# 15          17  종로구        청운효자동  448.0  0.075561  38.838253
# 16          18  종로구          혜화동  610.0  0.102884  52.882442

# %%
li=df_dong['구'].unique().tolist()
li=sorted(li)
li
# Out:
# ['강남구',
#  '강동구',
#  '강북구',
#  '강서구',
#  '관악구',
#  '광진구',
#  '구로구',
#  '금천구',
#  '노원구',
#  '도봉구',
#  '동대문구',
#  '동작구',
#  '마포구',
#  '서대문구',
#  '서초구',
#  '성동구',
#  '성북구',
#  '송파구',
#  '양천구',
#  '영등포구',
#  '용산구',
#  '은평구',
#  '종로구',
#  '중구',
#  '중랑구']

# %%
df_dong=df_dong.sort_values('구')
df_dong
# Out:
#      Unnamed: 0    구     동       계        비율     장애인취업자       대상자_수  \
# 363         387  강남구  대치1동   282.0  0.018575   2.321828   74.317086
# 375         399  강남구   세곡동  1942.0  0.127915  15.989329  511.786458
# 367         391  강남구  도곡1동   380.0  0.025030   3.128705  100.143591
# 358         382  강남구   신사동   396.0  0.026084   3.260440  104.360163
# 359         383  강남구  논현1동   548.0  0.036095   4.511922  144.417600
# ..          ...  ...   ...     ...       ...        ...         ...
# 94          102  중랑구  면목2동  1239.0  0.060864   7.607948  243.515204
# 109         117  중랑구  망우본동  1777.0  0.087292  10.911480  349.254654
# 100         108  중랑구  중화1동   941.0  0.046225   5.778111  184.945768
# 99          107  중랑구  상봉2동   842.0  0.041362   5.170212  165.488137
# 103         111  중랑구   묵2동   928.0  0.045586   5.698286  182.390726
#
#           수급자_수
# 363   53.792122
# 375  370.440785
# 367   72.485838
# 358   75.537874
# 359  104.532209
# ..          ...
# 94   176.260942
# 109  252.797170
# 100  133.867269
# 99   119.783465
# 103  132.017881
#
# [426 rows x 8 columns]

# %%
df_worker = pd.DataFrame(columns=['구', '동', '장애인취업자', '대상자수','수급자수'])
df_worker['구'] = df_dong['구']
df_worker['동'] = df_dong['동']
df_worker
# Out:
#        구     동 장애인취업자 대상자수 수급자수
# 363  강남구  대치1동    NaN  NaN  NaN
# 375  강남구   세곡동    NaN  NaN  NaN
# 367  강남구  도곡1동    NaN  NaN  NaN
# 358  강남구   신사동    NaN  NaN  NaN
# 359  강남구  논현1동    NaN  NaN  NaN
# ..   ...   ...    ...  ...  ...
# 94   중랑구  면목2동    NaN  NaN  NaN
# 109  중랑구  망우본동    NaN  NaN  NaN
# 100  중랑구  중화1동    NaN  NaN  NaN
# 99   중랑구  상봉2동    NaN  NaN  NaN
# 103  중랑구   묵2동    NaN  NaN  NaN
#
# [426 rows x 5 columns]

# %%
df_yeon = pd.read_csv('연금대상자및수급자.csv')
df_yeon = df_yeon.set_index('통계시군구명')
df_yeon
# Out:
#         대상자수  수급자수
# 통계시군구명
# 강남구     3776  2409
# 강동구     3847  2427
# 강북구     3494  2594
# 강서구     6627  5051
# 관악구     3764  2422
# 광진구     2171  1259
# 구로구     3418  2217
# 금천구     2100  1440
# 노원구     6650  5105
# 도봉구     2939  1995
# 동대문구    2706  1741
# 동작구     2792  1673
# 마포구     2698  1662
# 서대문구    2284  1428
# 서초구     2123  1113
# 성동구     1955  1183
# 성북구     3207  2026
# 송파구     4215  2461
# 양천구     3274  2143
# 영등포구    2569  1467
# 용산구     1391   793
# 은평구     4416  3217
#  21          24  중구   장충동  196.0  0.034789  22.195243   35.936812  22.056088
#  23          26  중구  을지로동   89.0  0.015797  10.078452   16.318246  10.015264
#  30          33  중구   청구동  629.0  0.111644  71.228612  115.327831  70.782038
#  26          29  중구   중림동  517.0  0.091764  58.545616   94.792510  58.178559
#  27          30  중구   신당동  400.0  0.070998  45.296415   73.340433  45.012425
#  28          31  중구   다산동  657.0  0.116613  74.399361  120.461661  73.932907
#  29          32  중구   약수동  851.0  0.151047  96.368122  156.031771  95.763933
#  31          34  중구   동화동  428.0  0.075967  48.467164   78.474263  48.163294
#  25          28  중구   황학동  498.0  0.088392  56.394036   91.308839  56.040469
#  24          27  중구  신당5동  482.0  0.085552  54.582180   88.375222  54.239972,
#       Unnamed: 0    구       동       계        비율     장애인취업자       대상자_수  \
#  107         115  중랑구    면목본동  1686.0  0.082822  10.352704  331.369357
#  106         114  중랑구    신내2동  1486.0  0.072997   9.124625  292.061011
#  105         113  중랑구    신내1동  1912.0  0.093923  11.740433  375.787788
#  104         112  중랑구    망우3동   957.0  0.047011   5.876357  188.090436
#  108         116  중랑구  면목3.8동  1284.0  0.063074   7.884266  252.359581
#  102         110  중랑구     묵1동  1478.0  0.072604   9.075502  290.488677
#  101         109  중랑구    중화2동  1496.0  0.073488   9.186029  294.026428
#  97          105  중랑구    면목7동  1041.0  0.051137   6.392150  204.599941
#  98          106  중랑구    상봉1동  1396.0  0.068576   8.571990  274.372255
#  96          104  중랑구    면목5동   633.0  0.031095   3.886869  124.410915
#  95          103  중랑구    면목4동  1261.0  0.061944   7.743037  247.839122
#  94          102  중랑구    면목2동  1239.0  0.060864   7.607948  243.515204
#  109         117  중랑구    망우본동  1777.0  0.087292  10.911480  349.254654
#  100         108  중랑구    중화1동   941.0  0.046225   5.778111  184.945768
#  99          107  중랑구    상봉2동   842.0  0.041362   5.170212  165.488137
#  103         111  중랑구     묵2동   928.0  0.045586   5.698286  182.390726
#
#            수급자_수
#  107  239.851452
#  106  211.399322
#  105  272.002358
#  104  136.143440
#  108  182.662671
#  102  210.261237
#  101  212.821929
#  97   148.093334
#  98   198.595864
#  96    90.050990
#  95   179.390676
#  94   176.260942
#  109  252.797170
#  100  133.867269
#  99   119.783465
#  103  132.017881  ]

# %%
df_result = pd.concat([lis[0],lis[1],lis[2],lis[3],lis[4],
                      lis[5],lis[6],lis[7],lis[8],lis[9],
                      lis[10],lis[11],lis[12],lis[13],lis[14],
                      lis[15],lis[16],lis[17],lis[18],lis[19],
                      lis[20],lis[21],lis[22],lis[23],lis[24]])
df_result
# Out:
#      Unnamed: 0    구     동       계        비율     장애인취업자       대상자_수  \
# 363         387  강남구  대치1동   282.0  0.018575  12.946516   70.137795
# 375         399  강남구   세곡동  1942.0  0.127915  89.156501  483.005665
# 367         391  강남구  도곡1동   380.0  0.025030  17.445659   94.511922
# 358         382  강남구   신사동   396.0  0.026084  18.180213   98.491371
# 359         383  강남구  논현1동   548.0  0.036095  25.158477  136.296140
# ..          ...  ...   ...     ...       ...        ...         ...
# 94          102  중랑구  면목2동  1239.0  0.060864   7.607948  243.515204
# 109         117  중랑구  망우본동  1777.0  0.087292  10.911480  349.254654
# 100         108  중랑구  중화1동   941.0  0.046225   5.778111  184.945768
# 99          107  중랑구  상봉2동   842.0  0.041362   5.170212  165.488137
# 103         111  중랑구   묵2동   928.0  0.045586   5.698286  182.390726
#
#           수급자_수
# 363   44.746278
# 375  308.146358
# 367   60.296404
# 358   62.835200
# 359   86.953761
# ..          ...
# 94   176.260942
# 109  252.797170
# 100  133.867269
# 99   119.783465
# 103  132.017881
#
# [426 rows x 8 columns]

# %%
df_result[df_result['구']=='노원구'].sum()
# Out:
# Unnamed: 0                                                 3382
# 구             노원구노원구노원구노원구노원구노원구노원구노원구노원구노원구노원구노원구노원구노원구노원구노...
# 동             상계5동상계1동중계2.3동상계6.7동월계1동상계10동상계9동상계8동상계2동공릉1동중...
# 계                                                       26904.0
# 비율                                                          1.0
# 장애인취업자                                                    107.0
# 대상자_수                                                    6650.0
# 수급자_수                                                    5105.0
# dtype: object

# %%
# df_result=df_result.drop(columns = ['Unnamed: 0'])
df_result= df_result.reset_index(drop =True)
df_result
# Out:
#        구     동       계        비율     장애인취업자       대상자_수       수급자_수
# 0    강남구  대치1동   282.0  0.018575  12.946516   70.137795   44.746278
# 1    강남구   세곡동  1942.0  0.127915  89.156501  483.005665  308.146358
# 2    강남구  도곡1동   380.0  0.025030  17.445659   94.511922   60.296404
# 3    강남구   신사동   396.0  0.026084  18.180213   98.491371   62.835200
# 4    강남구  논현1동   548.0  0.036095  25.158477  136.296140   86.953761
# ..   ...   ...     ...       ...        ...         ...         ...
# 421  중랑구  면목2동  1239.0  0.060864   7.607948  243.515204  176.260942
# 422  중랑구  망우본동  1777.0  0.087292  10.911480  349.254654  252.797170
# 423  중랑구  중화1동   941.0  0.046225   5.778111  184.945768  133.867269
# 424  중랑구  상봉2동   842.0  0.041362   5.170212  165.488137  119.783465
# 425  중랑구   묵2동   928.0  0.045586   5.698286  182.390726  132.017881
#
# [426 rows x 7 columns]

# %%
import math as m
df_result[['장애인취업자','대상자_수','수급자_수']] = round(df_result[['장애인취업자','대상자_수','수급자_수']])
df_result
# Out:
#        구     동       계        비율  장애인취업자  대상자_수  수급자_수
# 0    강남구  대치1동   282.0  0.018575    13.0   70.0   45.0
# 1    강남구   세곡동  1942.0  0.127915    89.0  483.0  308.0
# 2    강남구  도곡1동   380.0  0.025030    17.0   95.0   60.0
# 3    강남구   신사동   396.0  0.026084    18.0   98.0   63.0
# 4    강남구  논현1동   548.0  0.036095    25.0  136.0   87.0
# ..   ...   ...     ...       ...     ...    ...    ...
# 421  중랑구  면목2동  1239.0  0.060864     8.0  244.0  176.0
# 422  중랑구  망우본동  1777.0  0.087292    11.0  349.0  253.0
# 423  중랑구  중화1동   941.0  0.046225     6.0  185.0  134.0
# 424  중랑구  상봉2동   842.0  0.041362     5.0  165.0  120.0
# 425  중랑구   묵2동   928.0  0.045586     6.0  182.0  132.0
#
# [426 rows x 7 columns]

# %%
df_result.to_csv('취업자_연금대상자_수급자.csv')
